# %%
import pandas as pd

# %%
df=pd.read_csv(r"R:\case study\All_ViewingActivity.csv\All_ViewingActivity.csv")
df
# Out:
#      Profile Name           Start Time  Duration  \
# 0          User 1  2022-04-28 16:08:56  00:00:06
# 1          User 1  2022-04-28 15:54:30  00:09:39
# 2          User 1  2022-04-28 15:53:20  00:00:06
# 3          User 1  2022-04-28 15:52:18  00:00:15
# 4          User 1  2022-04-28 15:49:11  00:01:45
# ...           ...                  ...       ...
# 9987       User 5  2023-01-07 18:41:03  00:00:26
# 9988       User 5  2023-01-07 15:44:54  00:02:14
# 9989       User 5  2023-01-07 15:13:36  00:21:11
# 9990       User 5  2023-01-07 15:13:26  00:00:06
# 9991       User 5  2023-01-07 15:13:19  00:00:04
#
#                            Attributes  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 9987                              NaN
# 9988                              NaN
# ...

# %% [markdown]
# ## date

# %%
t001 2023-01-06 phone

# %%
2023-01-06 : Year, month , day , week , wekkend , quarter , semesester

# %%
## date time inttelegece

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9992 entries, 0 to 9991
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Profile Name             9992 non-null   object
#  1   Start Time               9992 non-null   object
#  2   Duration                 9992 non-null   object
#  3   Attributes               1399 non-null   object
#  4   Title                    9992 non-null   object
#  5   Supplemental Video Type  1845 non-null   object
#  6   Device Type              9992 non-null   object
#  7   Bookmark                 9992 non-null   object
#  8   Latest Bookmark          9992 non-null   object
#  9   Country                  9992 non-null   object
# dtypes: object(10)
# memory usage: 780.8+ KB

# %% [markdown]
# ## data trype convert

# %%
df=pd.DataFrame({"id":[1,2,3,4],"Name":["ram","shyam","hari","gopal"],"salary":['20000',2000,"rs 35000",6000]})

# %%
df
# Out:
#    id   Name    salary
# 0   1    ram  rs 20000
# 1   2  shyam      2000
# 2   3   hari     35000
# 3   4  gopal      6000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      4 non-null      int64
#  1   Name    4 non-null      object
#  2   salary  4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes

# %%
10+30
# Out:
# 40

# %%
'10'+'30'
# Out:
# '1030'

# %% [markdown]
# ### Conver the column data into Numeric columns

# %%
df
# Out:
#    id   Name    salary
# 0   1    ram  rs 20000
# 1   2  shyam      2000
# 2   3   hari     35000
# 3   4  gopal      6000

# %%
df['salary']
# Out:
# 0       20000
# 1        2000
# 2    rs 35000
# 3        6000
# Name: salary, dtype: object

# %%
df['salary']=pd.to_numeric(df['salary'],errors="coerce")      # iggnore , raise , coerce

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      4 non-null      int64
#  1   Name    4 non-null      object
#  2   salary  3 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 228.0+ bytes

# %% [markdown]
# ### date time

# %%
df[['Title',"Start Time"]]
# Out:
#                                                   Title           Start Time
# 0                                        Chernobyl 1986  2022-04-28 16:08:56
# 1             13 Hours: The Secret Soldiers of Benghazi  2022-04-28 15:54:30
# 2                                   Saving Private Ryan  2022-04-28 15:53:20
# 3                                                 Mosul  2022-04-28 15:52:18
# 4                                             12 Strong  2022-04-28 15:49:11
# ...                                                 ...                  ...
# 9987                 Slumberland - Fast Laughs - Clip 3  2023-01-07 18:41:03
# 9988  Wednesday: Season 1: Wednesday's Child Is Full...  2023-01-07 15:44:54
# 9989  Wednesday: Season 1: Wednesday's Child Is Full...  2023-01-07 15:13:36
# 9990     Season 1 Genre Specific Moment Clip: Wednesday  2023-01-07 15:13:26
# 9991            Naruto Shippuden: Season 1_hook_03_16x9  2023-01-07 15:13:19
#
# [9992 rows x 2 columns]

# %%
"2022-13-45"

# %%
df=pd.DataFrame({"id":[1,2,3,4,5,6],"Name":["ram","shyam","hari","gopal","suresh","gopal"],"join_date":
                 ["2022-01-05","2034-34-12","2022-45-80","2024-01-08","09 march ,2030","2023-19-08"]})
df
# Out:
#    id    Name       join_date
# 0   1     ram      2022-01-05
# 1   2   shyam      2034-34-12
# 2   3    hari      2022-45-80
# 3   4   gopal      2024-01-08
# 4   5  suresh  09 march ,2030
# 5   6   gopal      2023-19-08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         5 non-null      int64
#  1   Name       5 non-null      object
#  2   join_date  5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes

# %%
pd.to_datetime(df['join_date'],format='mixed',errors="coerce")
# Out:
# 0   2022-01-05
# 1          NaT
# 2          NaT
# 3   2024-01-08
# 4   2030-03-09
# 5          NaT
# Name: join_date, dtype: datetime64[ns]

# %%
df
# Out:
#    id    Name       join_date
# 0   1     ram      2022-01-05
# 1   2   shyam      2034-34-12
# 2   3    hari      2022-45-80
# 3   4   gopal      2024-01-08
# 4   5  suresh  09 march ,2030
# 5   6   gopal      2023-19-08

# %% [markdown]
# ## extract date methids

# %%
temp=df[['Start Time',"Title"]]
temp
# Out:
#                Start Time                                              Title
# 0     2022-04-28 16:08:56                                     Chernobyl 1986
# 1     2022-04-28 15:54:30          13 Hours: The Secret Soldiers of Benghazi
# 2     2022-04-28 15:53:20                                Saving Private Ryan
# 3     2022-04-28 15:52:18                                              Mosul
# 4     2022-04-28 15:49:11                                          12 Strong
# ...                   ...                                                ...
# 9987  2023-01-07 18:41:03                 Slumberland - Fast Laughs - Clip 3
# 9988  2023-01-07 15:44:54  Wednesday: Season 1: Wednesday's Child Is Full...
# 9989  2023-01-07 15:13:36  Wednesday: Season 1: Wednesday's Child Is Full...
# 9990  2023-01-07 15:13:26     Season 1 Genre Specific Moment Clip: Wednesday
# 9991  2023-01-07 15:13:19            Naruto Shippuden: Season 1_hook_03_16x9
#
# [9992 rows x 2 columns]

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9992 entries, 0 to 9991
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Start Time  9992 non-null   object
#  1   Title       9992 non-null   object
# dtypes: object(2)
# memory usage: 156.3+ KB

# %%
temp['date_time']=pd.to_datetime(temp['Start Time'])

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9992 entries, 0 to 9991
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Start Time  9992 non-null   object
#  1   Title       9992 non-null   object
#  2   date_time   9992 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 234.3+ KB

# %% [markdown]
# ## year , quarter , ,,,...

# %%
temp.head()
# Out:
#             Start Time                                      Title  \
# 0  2022-04-28 16:08:56                             Chernobyl 1986
# 1  2022-04-28 15:54:30  13 Hours: The Secret Soldiers of Benghazi
# 2  2022-04-28 15:53:20                        Saving Private Ryan
# 3  2022-04-28 15:52:18                                      Mosul
# 4  2022-04-28 15:49:11                                  12 Strong
#
#             date_time
# 0 2022-04-28 16:08:56
# 1 2022-04-28 15:54:30
# 2 2022-04-28 15:53:20
# 3 2022-04-28 15:52:18
# 4 2022-04-28 15:49:11

# %%
temp['year']=temp['date_time'].dt.year

# %%
temp['month_nymeric']=temp['date_time'].dt.month

# %%
temp['month_name']=temp['date_time'].dt.month_name()
temp
# Out:
#                Start Time                                              Title  \
# 0     2022-04-28 16:08:56                                     Chernobyl 1986
# 1     2022-04-28 15:54:30          13 Hours: The Secret Soldiers of Benghazi
# 2     2022-04-28 15:53:20                                Saving Private Ryan
# 3     2022-04-28 15:52:18                                              Mosul
# 4     2022-04-28 15:49:11                                          12 Strong
# ...                   ...                                                ...
# 9987  2023-01-07 18:41:03                 Slumberland - Fast Laughs - Clip 3
# 9988  2023-01-07 15:44:54  Wednesday: Season 1: Wednesday's Child Is Full...
# 9989  2023-01-07 15:13:36  Wednesday: Season 1: Wednesday's Child Is Full...
# 9990  2023-01-07 15:13:26     Season 1 Genre Specific Moment Clip: Wednesday
# 9991  2023-01-07 15:13:19            Naruto Shippuden: Season 1_hook_03_16x9
#
# ...

# %% [raw]
# AttributeDescriptionOutput Example.dt.yearThe year of the date2024.dt.monthThe month as January=1, December=125.dt.dayThe day of the month20.dt.hourThe hour (0-23)14.dt.minuteThe minute (0-59)30.dt.secondThe second (0-59)15.dt.dateReturns standard Python datetime.date objects2024-05-20.dt.timeReturns standard Python datetime.time objects14:30:15

# %%
temp['quarter']="Q"+(temp['date_time'].dt.quarter).apply(numeric_to_string)

# %%
def numeric_to_string(n_value):
    return str(n_value)

# %%
numeric_to_string(10)
# Out:
# '10'

# %%
temp
# Out:
#                Start Time                                              Title  \
# 0     2022-04-28 16:08:56                                     Chernobyl 1986
# 1     2022-04-28 15:54:30          13 Hours: The Secret Soldiers of Benghazi
# 2     2022-04-28 15:53:20                                Saving Private Ryan
# 3     2022-04-28 15:52:18                                              Mosul
# 4     2022-04-28 15:49:11                                          12 Strong
# ...                   ...                                                ...
# 9987  2023-01-07 18:41:03                 Slumberland - Fast Laughs - Clip 3
# 9988  2023-01-07 15:44:54  Wednesday: Season 1: Wednesday's Child Is Full...
# 9989  2023-01-07 15:13:36  Wednesday: Season 1: Wednesday's Child Is Full...
# 9990  2023-01-07 15:13:26     Season 1 Genre Specific Moment Clip: Wednesday
# 9991  2023-01-07 15:13:19            Naruto Shippuden: Season 1_hook_03_16x9
#
# ...

# %%
temp['day']=temp['date_time'].dt.day

# %%
temp
# Out:
#                Start Time                                              Title  \
# 0     2022-04-28 16:08:56                                     Chernobyl 1986
# 1     2022-04-28 15:54:30          13 Hours: The Secret Soldiers of Benghazi
# 2     2022-04-28 15:53:20                                Saving Private Ryan
# 3     2022-04-28 15:52:18                                              Mosul
# 4     2022-04-28 15:49:11                                          12 Strong
# ...                   ...                                                ...
# 9987  2023-01-07 18:41:03                 Slumberland - Fast Laughs - Clip 3
# 9988  2023-01-07 15:44:54  Wednesday: Season 1: Wednesday's Child Is Full...
# 9989  2023-01-07 15:13:36  Wednesday: Season 1: Wednesday's Child Is Full...
# 9990  2023-01-07 15:13:26     Season 1 Genre Specific Moment Clip: Wednesday
# 9991  2023-01-07 15:13:19            Naruto Shippuden: Season 1_hook_03_16x9
#
# ...

# %%
temp['day_name']=temp['date_time'].dt.day_name().str[0:3]

# %%
temp['date_time'].dt.day_name().apply(extract_3)
# Out:
# 0       Thu
# 1       Thu
# 2       Thu
# 3       Thu
# 4       Thu
#        ...
# 9987    Sat
# 9988    Sat
# 9989    Sat
# 9990    Sat
# 9991    Sat
# Name: date_time, Length: 9992, dtype: object

# %%
temp
# Out:
#                Start Time                                              Title  \
# 0     2022-04-28 16:08:56                                     Chernobyl 1986
# 1     2022-04-28 15:54:30          13 Hours: The Secret Soldiers of Benghazi
# 2     2022-04-28 15:53:20                                Saving Private Ryan
# 3     2022-04-28 15:52:18                                              Mosul
# 4     2022-04-28 15:49:11                                          12 Strong
# ...                   ...                                                ...
# 9987  2023-01-07 18:41:03                 Slumberland - Fast Laughs - Clip 3
# 9988  2023-01-07 15:44:54  Wednesday: Season 1: Wednesday's Child Is Full...
# 9989  2023-01-07 15:13:36  Wednesday: Season 1: Wednesday's Child Is Full...
# 9990  2023-01-07 15:13:26     Season 1 Genre Specific Moment Clip: Wednesday
# 9991  2023-01-07 15:13:19            Naruto Shippuden: Season 1_hook_03_16x9
#
# ...

# %%
temp['date_time'].dt.date
# Out:
# 0       2022-04-28
# 1       2022-04-28
# 2       2022-04-28
# 3       2022-04-28
# 4       2022-04-28
#            ...
# 9987    2023-01-07
# 9988    2023-01-07
# 9989    2023-01-07
# 9990    2023-01-07
# 9991    2023-01-07
# Name: date_time, Length: 9992, dtype: object

# %%
temp['date_time'].dt.time
# Out:
# 0       16:08:56
# 1       15:54:30
# 2       15:53:20
# 3       15:52:18
# 4       15:49:11
#           ...
# 9987    18:41:03
# 9988    15:44:54
# 9989    15:13:36
# 9990    15:13:26
# 9991    15:13:19
# Name: date_time, Length: 9992, dtype: object

# %%
temp['date_time'].dt.date
# Out:
# 0       2022-04-28
# 1       2022-04-28
# 2       2022-04-28
# 3       2022-04-28
# 4       2022-04-28
#            ...
# 9987    2023-01-07
# 9988    2023-01-07
# 9989    2023-01-07
# 9990    2023-01-07
# 9991    2023-01-07
# Name: date_time, Length: 9992, dtype: object

# %%
temp['time']=temp['date_time'].dt.time
temp
# Out:
#                Start Time                                              Title  \
# 0     2022-04-28 16:08:56                                     Chernobyl 1986
# 1     2022-04-28 15:54:30          13 Hours: The Secret Soldiers of Benghazi
# 2     2022-04-28 15:53:20                                Saving Private Ryan
# 3     2022-04-28 15:52:18                                              Mosul
# 4     2022-04-28 15:49:11                                          12 Strong
# ...                   ...                                                ...
# 9987  2023-01-07 18:41:03                 Slumberland - Fast Laughs - Clip 3
# 9988  2023-01-07 15:44:54  Wednesday: Season 1: Wednesday's Child Is Full...
# 9989  2023-01-07 15:13:36  Wednesday: Season 1: Wednesday's Child Is Full...
# 9990  2023-01-07 15:13:26     Season 1 Genre Specific Moment Clip: Wednesday
# 9991  2023-01-07 15:13:19            Naruto Shippuden: Season 1_hook_03_16x9
#
# ...

# %%
temp['date_time'].dt.hour
# Out:
# 0       16
# 1       15
# 2       15
# 3       15
# 4       15
#         ..
# 9987    18
# 9988    15
# 9989    15
# 9990    15
# 9991    15
# Name: date_time, Length: 9992, dtype: int32

# %%
temp['date_time'].dt.minute
# Out:
# 0        8
# 1       54
# 2       53
# 3       52
# 4       49
#         ..
# 9987    41
# 9988    44
# 9989    13
# 9990    13
# 9991    13
# Name: date_time, Length: 9992, dtype: int32

# %%
temp['date_time'].dt.second
# Out:
# 0       56
# 1       30
# 2       20
# 3       18
# 4       11
#         ..
# 9987     3
# 9988    54
# 9989    36
# 9990    26
# 9991    19
# Name: date_time, Length: 9992, dtype: int32

# %% [markdown]
# # Time Delta

# %%
temp['date_time']
# Out:
# 0      2022-04-28 16:08:56
# 1      2022-04-28 15:54:30
# 2      2022-04-28 15:53:20
# 3      2022-04-28 15:52:18
# 4      2022-04-28 15:49:11
#                ...
# 9987   2023-01-07 18:41:03
# 9988   2023-01-07 15:44:54
# 9989   2023-01-07 15:13:36
# 9990   2023-01-07 15:13:26
# 9991   2023-01-07 15:13:19
# Name: date_time, Length: 9992, dtype: datetime64[ns]

# %%
df['date'] + pd.Timedelta(days=7)

# %%
temp['date_time']+ pd.Timedelta(days=120)
# Out:
# 0      2022-08-26 16:08:56
# 1      2022-08-26 15:54:30
# 2      2022-08-26 15:53:20
# 3      2022-08-26 15:52:18
# 4      2022-08-26 15:49:11
#                ...
# 9987   2023-05-07 18:41:03
# 9988   2023-05-07 15:44:54
# 9989   2023-05-07 15:13:36
# 9990   2023-05-07 15:13:26
# 9991   2023-05-07 15:13:19
# Name: date_time, Length: 9992, dtype: datetime64[ns]

# %% [raw]
# ValueError: cannot construct a Timedelta from the passed arguments, allowed keywords are [weeks, days, hours, minutes, seconds, milliseconds, microseconds, nanoseconds]

# %%
temp['date_time']+ pd.Timedelta(weeks=2)
# Out:
# 0      2022-05-12 16:08:56
# 1      2022-05-12 15:54:30
# 2      2022-05-12 15:53:20
# 3      2022-05-12 15:52:18
# 4      2022-05-12 15:49:11
#                ...
# 9987   2023-01-21 18:41:03
# 9988   2023-01-21 15:44:54
# 9989   2023-01-21 15:13:36
# 9990   2023-01-21 15:13:26
# 9991   2023-01-21 15:13:19
# Name: date_time, Length: 9992, dtype: datetime64[ns]

# %%
temp['date_time']+ pd.Timedelta(hours=48)
# Out:
# 0      2022-04-30 16:08:56
# 1      2022-04-30 15:54:30
# 2      2022-04-30 15:53:20
# 3      2022-04-30 15:52:18
# 4      2022-04-30 15:49:11
#                ...
# 9987   2023-01-09 18:41:03
# 9988   2023-01-09 15:44:54
# 9989   2023-01-09 15:13:36
# 9990   2023-01-09 15:13:26
# 9991   2023-01-09 15:13:19
# Name: date_time, Length: 9992, dtype: datetime64[ns]

# %%
temp['date_time']
# Out:
# 0      2022-04-28 16:08:56
# 1      2022-04-28 15:54:30
# 2      2022-04-28 15:53:20
# 3      2022-04-28 15:52:18
# 4      2022-04-28 15:49:11
#                ...
# 9987   2023-01-07 18:41:03
# 9988   2023-01-07 15:44:54
# 9989   2023-01-07 15:13:36
# 9990   2023-01-07 15:13:26
# 9991   2023-01-07 15:13:19
# Name: date_time, Length: 9992, dtype: datetime64[ns]

# %% [markdown]
# ## Months Off set

# %%
temp['date_time']
# Out:
# 0      2022-04-28 16:08:56
# 1      2022-04-28 15:54:30
# 2      2022-04-28 15:53:20
# 3      2022-04-28 15:52:18
# 4      2022-04-28 15:49:11
#                ...
# 9987   2023-01-07 18:41:03
# 9988   2023-01-07 15:44:54
# 9989   2023-01-07 15:13:36
# 9990   2023-01-07 15:13:26
# 9991   2023-01-07 15:13:19
# Name: date_time, Length: 9992, dtype: datetime64[ns]

# %%
temp['date_time'] + pd.DateOffset(months=3)
# Out:
# 0      2022-07-28 16:08:56
# 1      2022-07-28 15:54:30
# 2      2022-07-28 15:53:20
# 3      2022-07-28 15:52:18
# 4      2022-07-28 15:49:11
#                ...
# 9987   2023-04-07 18:41:03
# 9988   2023-04-07 15:44:54
# 9989   2023-04-07 15:13:36
# 9990   2023-04-07 15:13:26
# 9991   2023-04-07 15:13:19
# Name: date_time, Length: 9992, dtype: datetime64[ns]

# %%
temp['date_time'] + pd.DateOffset(years=3)
# Out:
# 0      2025-04-28 16:08:56
# 1      2025-04-28 15:54:30
# 2      2025-04-28 15:53:20
# 3      2025-04-28 15:52:18
# 4      2025-04-28 15:49:11
#                ...
# 9987   2026-01-07 18:41:03
# 9988   2026-01-07 15:44:54
# 9989   2026-01-07 15:13:36
# 9990   2026-01-07 15:13:26
# 9991   2026-01-07 15:13:19
# Name: date_time, Length: 9992, dtype: datetime64[ns]

# %%
temp['date_time']
# Out:
# 0      2022-04-28 16:08:56
# 1      2022-04-28 15:54:30
# 2      2022-04-28 15:53:20
# 3      2022-04-28 15:52:18
# 4      2022-04-28 15:49:11
#                ...
# 9987   2023-01-07 18:41:03
# 9988   2023-01-07 15:44:54
# 9989   2023-01-07 15:13:36
# 9990   2023-01-07 15:13:26
# 9991   2023-01-07 15:13:19
# Name: date_time, Length: 9992, dtype: datetime64[ns]

# %%
temp['date_time']+ pd.Timedelta(hours=-48)
# Out:
# 0      2022-04-26 16:08:56
# 1      2022-04-26 15:54:30
# 2      2022-04-26 15:53:20
# 3      2022-04-26 15:52:18
# 4      2022-04-26 15:49:11
#                ...
# 9987   2023-01-05 18:41:03
# 9988   2023-01-05 15:44:54
# 9989   2023-01-05 15:13:36
# 9990   2023-01-05 15:13:26
# 9991   2023-01-05 15:13:19
# Name: date_time, Length: 9992, dtype: datetime64[ns]

# %%
temp['date_time']
# Out:
# 0      2022-04-28 16:08:56
# 1      2022-04-28 15:54:30
# 2      2022-04-28 15:53:20
# 3      2022-04-28 15:52:18
# 4      2022-04-28 15:49:11
#                ...
# 9987   2023-01-07 18:41:03
# 9988   2023-01-07 15:44:54
# 9989   2023-01-07 15:13:36
# 9990   2023-01-07 15:13:26
# 9991   2023-01-07 15:13:19
# Name: date_time, Length: 9992, dtype: datetime64[ns]

# %%
temp['date_time'] + pd.DateOffset(years=-3)
# Out:
# 0      2019-04-28 16:08:56
# 1      2019-04-28 15:54:30
# 2      2019-04-28 15:53:20
# 3      2019-04-28 15:52:18
# 4      2019-04-28 15:49:11
#                ...
# 9987   2020-01-07 18:41:03
# 9988   2020-01-07 15:44:54
# 9989   2020-01-07 15:13:36
# 9990   2020-01-07 15:13:26
# 9991   2020-01-07 15:13:19
# Name: date_time, Length: 9992, dtype: datetime64[ns]

# %%
"dob" : 2055-01-05

# %% [markdown]
# ### date difference

# %%
temp
# Out:
#                Start Time                                              Title  \
# 0     2022-04-28 16:08:56                                     Chernobyl 1986
# 1     2022-04-28 15:54:30          13 Hours: The Secret Soldiers of Benghazi
# 2     2022-04-28 15:53:20                                Saving Private Ryan
# 3     2022-04-28 15:52:18                                              Mosul
# 4     2022-04-28 15:49:11                                          12 Strong
# ...                   ...                                                ...
# 9987  2023-01-07 18:41:03                 Slumberland - Fast Laughs - Clip 3
# 9988  2023-01-07 15:44:54  Wednesday: Season 1: Wednesday's Child Is Full...
# 9989  2023-01-07 15:13:36  Wednesday: Season 1: Wednesday's Child Is Full...
# 9990  2023-01-07 15:13:26     Season 1 Genre Specific Moment Clip: Wednesday
# 9991  2023-01-07 15:13:19            Naruto Shippuden: Season 1_hook_03_16x9
#
# ...

# %%
pd.Timestamp.now()
# Out:
# Timestamp('2026-05-20 21:18:44.534839')

# %%
pd.Timestamp.now()-temp['date_time']
# Out:
# 0      1483 days 05:10:17.732972
# 1      1483 days 05:24:43.732972
# 2      1483 days 05:25:53.732972
# 3      1483 days 05:26:55.732972
# 4      1483 days 05:30:02.732972
#                   ...
# 9987   1229 days 02:38:10.732972
# 9988   1229 days 05:34:19.732972
# 9989   1229 days 06:05:37.732972
# 9990   1229 days 06:05:47.732972
# 9991   1229 days 06:05:54.732972
# Name: date_time, Length: 9992, dtype: timedelta64[ns]

# %%
pd.Timestamp.now()-temp['date_time']
# Out:
# 0      1483 days 05:11:48.766344
# 1      1483 days 05:26:14.766344
# 2      1483 days 05:27:24.766344
# 3      1483 days 05:28:26.766344
# 4      1483 days 05:31:33.766344
#                   ...
# 9987   1229 days 02:39:41.766344
# 9988   1229 days 05:35:50.766344
# 9989   1229 days 06:07:08.766344
# 9990   1229 days 06:07:18.766344
# 9991   1229 days 06:07:25.766344
# Name: date_time, Length: 9992, dtype: timedelta64[ns]

# %% [markdown]
# ### analysis

# %%
temp['year'].value_counts()
# Out:
# year
# 2022    6748
# 2023    2622
# 2021     622
# Name: count, dtype: int64

# %%
temp
# Out:
#                Start Time                                              Title  \
# 0     2022-04-28 16:08:56                                     Chernobyl 1986
# 1     2022-04-28 15:54:30          13 Hours: The Secret Soldiers of Benghazi
# 2     2022-04-28 15:53:20                                Saving Private Ryan
# 3     2022-04-28 15:52:18                                              Mosul
# 4     2022-04-28 15:49:11                                          12 Strong
# ...                   ...                                                ...
# 9987  2023-01-07 18:41:03                 Slumberland - Fast Laughs - Clip 3
# 9988  2023-01-07 15:44:54  Wednesday: Season 1: Wednesday's Child Is Full...
# 9989  2023-01-07 15:13:36  Wednesday: Season 1: Wednesday's Child Is Full...
# 9990  2023-01-07 15:13:26     Season 1 Genre Specific Moment Clip: Wednesday
# 9991  2023-01-07 15:13:19            Naruto Shippuden: Season 1_hook_03_16x9
#
# ...

# %%
temp.groupby(['year','month_nymeric','month_name'])['Title'].count()
# Out:
# year  month_nymeric  month_name
# 2021  10             October         6
#       11             November      129
#       12             December      487
# 2022  1              January       637
#       2              February      926
#       3              March         686
#       4              April         901
#       5              May           420
#       6              June          958
#       7              July          443
#       8              August        643
#       9              September     250
#       10             October       301
#       11             November      397
#       12             December      186
# 2023  1              January       523
#       2              February      440
#       3              March         335
#       4              April         485
#       5              May           558
#       6              June          281
# Name: Title, dtype: int64

# %%
temp
# Out:
#                Start Time                                              Title  \
# 0     2022-04-28 16:08:56                                     Chernobyl 1986
# 1     2022-04-28 15:54:30          13 Hours: The Secret Soldiers of Benghazi
# 2     2022-04-28 15:53:20                                Saving Private Ryan
# 3     2022-04-28 15:52:18                                              Mosul
# 4     2022-04-28 15:49:11                                          12 Strong
# ...                   ...                                                ...
# 9987  2023-01-07 18:41:03                 Slumberland - Fast Laughs - Clip 3
# 9988  2023-01-07 15:44:54  Wednesday: Season 1: Wednesday's Child Is Full...
# 9989  2023-01-07 15:13:36  Wednesday: Season 1: Wednesday's Child Is Full...
# 9990  2023-01-07 15:13:26     Season 1 Genre Specific Moment Clip: Wednesday
# 9991  2023-01-07 15:13:19            Naruto Shippuden: Season 1_hook_03_16x9
#
# ...

# %%
temp.groupby(['year','month_nymeric','month_name'])['Title'].count()
# Out:
# year  month_nymeric  month_name
# 2021  10             October         6
#       11             November      129
#       12             December      487
# 2022  1              January       637
#       2              February      926
#       3              March         686
#       4              April         901
#       5              May           420
#       6              June          958
#       7              July          443
#       8              August        643
#       9              September     250
#       10             October       301
#       11             November      397
#       12             December      186
# 2023  1              January       523
#       2              February      440
#       3              March         335
#       4              April         485
#       5              May           558
#       6              June          281
# Name: Title, dtype: int64

# %%
temp['day_name'].value_counts()
# Out:
# day_name
# Sun    1811
# Sat    1456
# Mon    1448
# Fri    1423
# Wed    1329
# Tue    1316
# Thu    1209
# Name: count, dtype: int64

# %%
temp['hour']=temp['date_time'].dt.hour
temp
# Out:
#                Start Time                                              Title  \
# 0     2022-04-28 16:08:56                                     Chernobyl 1986
# 1     2022-04-28 15:54:30          13 Hours: The Secret Soldiers of Benghazi
# 2     2022-04-28 15:53:20                                Saving Private Ryan
# 3     2022-04-28 15:52:18                                              Mosul
# 4     2022-04-28 15:49:11                                          12 Strong
# ...                   ...                                                ...
# 9987  2023-01-07 18:41:03                 Slumberland - Fast Laughs - Clip 3
# 9988  2023-01-07 15:44:54  Wednesday: Season 1: Wednesday's Child Is Full...
# 9989  2023-01-07 15:13:36  Wednesday: Season 1: Wednesday's Child Is Full...
# 9990  2023-01-07 15:13:26     Season 1 Genre Specific Moment Clip: Wednesday
# 9991  2023-01-07 15:13:19            Naruto Shippuden: Season 1_hook_03_16x9
#
# ...

# %%
temp['hour'].value_counts().sort_index().plot(kind='line')
# Out:
# <Axes: xlabel='hour'>

# %%
temp
# Out:
#                Start Time                                              Title  \
# 0     2022-04-28 16:08:56                                     Chernobyl 1986
# 1     2022-04-28 15:54:30          13 Hours: The Secret Soldiers of Benghazi
# 2     2022-04-28 15:53:20                                Saving Private Ryan
# 3     2022-04-28 15:52:18                                              Mosul
# 4     2022-04-28 15:49:11                                          12 Strong
# ...                   ...                                                ...
# 9987  2023-01-07 18:41:03                 Slumberland - Fast Laughs - Clip 3
# 9988  2023-01-07 15:44:54  Wednesday: Season 1: Wednesday's Child Is Full...
# 9989  2023-01-07 15:13:36  Wednesday: Season 1: Wednesday's Child Is Full...
# 9990  2023-01-07 15:13:26     Season 1 Genre Specific Moment Clip: Wednesday
# 9991  2023-01-07 15:13:19            Naruto Shippuden: Season 1_hook_03_16x9
#
# ...

# %%
## Growth :

yoy
mom
percent_of_total
pivot table

# %%
df['order_date'] - df['shipeed_date']
