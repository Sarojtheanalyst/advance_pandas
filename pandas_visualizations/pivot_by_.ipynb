# %%
import pandas as pd

# %%
df=pd.read_csv(r"movs.csv")
df
# Out:
#                            Series_Title  Released_Year  Runtime   Genre  \
# 0                             Chinatown           1974      130   Drama
# 1       The Girl with the Dragon Tattoo           2011      158   Crime
# 2                          Nueve reinas           2000      114   Crime
# 3    Close Encounters of the Third Kind           1977      138   Drama
# 4                                 Joker           2019      122   Crime
# ..                                  ...            ...      ...     ...
# 295                         Kumonosu-jô           1957      110   Drama
# 296                        Falling Down           1993      113  Action
# 297                The Royal Tenenbaums           2001      110  Comedy
# 298                     Midnight Cowboy           1969      113   Drama
# 299                         Kai po che!           2013      130   Drama
#
#      IMDB_Rating          Director             Star1  No_of_Votes  \
# ...

# %% [markdown]
# ## 1) Find the most common star (actor) in the dataset.

# %%
comon=df['Star1'].value_counts()
comon[comon>=4]
# Out:
# Star1
# Johnny Depp          6
# Humphrey Bogart      5
# Christian Bale       5
# Leonardo DiCaprio    5
# Al Pacino            4
# Tom Hanks            4
# Name: count, dtype: int64

# %% [markdown]
# # 2) List all movies that have both an IMDb rating greater than 7 and a metascore greater than 70.

# %%
df[(df['IMDB_Rating']>7) & (df['Metascore']>70)]
# Out:
#                            Series_Title  Released_Year  Runtime   Genre  \
# 0                             Chinatown           1974      130   Drama
# 1       The Girl with the Dragon Tattoo           2011      158   Crime
# 2                          Nueve reinas           2000      114   Crime
# 3    Close Encounters of the Third Kind           1977      138   Drama
# 6                      Edge of Tomorrow           2014      113  Action
# ..                                  ...            ...      ...     ...
# 292                       The Godfather           1972      175   Crime
# 293                   Road to Perdition           2002      117   Crime
# 294                             Bin-jip           2004       88   Crime
# 297                The Royal Tenenbaums           2001      110  Comedy
# 298                     Midnight Cowboy           1969      113   Drama
#
#      IMDB_Rating              Director             Star1  No_of_Votes  \
# ...

# %% [markdown]
# # 3) Find all movies directed by a specific director (e.g., "Steven Spielberg").

# %%
df[df['Director']=="Steven Spielberg"]
# Out:
#                            Series_Title  Released_Year  Runtime      Genre  \
# 3    Close Encounters of the Third Kind           1977      138      Drama
# 121                 Catch Me If You Can           2002      141  Biography
#
#      IMDB_Rating          Director              Star1  No_of_Votes  \
# 3            7.6  Steven Spielberg   Richard Dreyfuss       184966
# 121          8.1  Steven Spielberg  Leonardo DiCaprio       832846
#
#            Gross  Metascore
# 3    132088635.0       90.0
# 121  164615351.0       75.0

# %% [markdown]
# # 4) Get the average gross revenue per genre.

# %%
df['Gros_in_m']=(df['Gross']/1000000).apply(lambda x : round(x,2))

# %%
df.groupby('Genre')['Gros_in_m'].mean()
# Out:
# Genre
# Action       184.269600
# Adventure    103.430769
# Animation    183.270000
# Biography    118.219655
# Comedy        73.052800
# Crime         84.246486
# Drama        101.360465
# Fantasy      337.570000
# Film-Noir      0.450000
# Horror        29.310000
# Mystery       14.380000
# Western        5.320000
# Name: Gros_in_m, dtype: float64

# %%
df.groupby('Genre')['Gros_in_m'].mean().index
# Out:
# Index(['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime',
#        'Drama', 'Fantasy', 'Film-Noir', 'Horror', 'Mystery', 'Western'],
#       dtype='object', name='Genre')

# %%
df.groupby('Genre')['Gros_in_m'].mean().values
# Out:
# array([184.2696    , 103.43076923, 183.27      , 118.21965517,
#         73.0528    ,  84.24648649, 101.36046512, 337.57      ,
#          0.45      ,  29.31      ,  14.38      ,   5.32      ])

# %%
pd.DataFrame(df.groupby('Genre')['Gros_in_m'].mean())
# Out:
#             Gros_in_m
# Genre
# Action     184.269600
# Adventure  103.430769
# Animation  183.270000
# Biography  118.219655
# Comedy      73.052800
# Crime       84.246486
# Drama      101.360465
# Fantasy    337.570000
# Film-Noir    0.450000
# Horror      29.310000
# Mystery     14.380000
# Western      5.320000

# %%
df.groupby('Genre')['Gros_in_m'].mean().sort_index(ascending=False)
# Out:
# Genre
# Western        5.320000
# Mystery       14.380000
# Horror        29.310000
# Film-Noir      0.450000
# Fantasy      337.570000
# Drama        101.360465
# Crime         84.246486
# Comedy        73.052800
# Biography    118.219655
# Animation    183.270000
# Adventure    103.430769
# Action       184.269600
# Name: Gros_in_m, dtype: float64

# %%
df.groupby('Genre')['Gros_in_m'].mean().sort_values(ascending=False)
# Out:
# Genre
# Fantasy      337.570000
# Action       184.269600
# Animation    183.270000
# Biography    118.219655
# Adventure    103.430769
# Drama        101.360465
# Crime         84.246486
# Comedy        73.052800
# Horror        29.310000
# Mystery       14.380000
# Western        5.320000
# Film-Noir      0.450000
# Name: Gros_in_m, dtype: float64

# %%
df.groupby('Genre')['Gros_in_m'].mean().sort_values(ascending=False).head(5)
# Out:
# Genre
# Fantasy      337.570000
# Action       184.269600
# Animation    183.270000
# Biography    118.219655
# Adventure    103.430769
# Name: Gros_in_m, dtype: float64

# %%
df.groupby('Genre')['Gros_in_m'].mean().sort_values(ascending=False).head(5).plot(kind='barh')
# Out:
# <Axes: ylabel='Genre'>

# %% [markdown]
# ## 5) Find the top 10 highest-grossing movies.

# %%
df.nlargest(10,"Gros_in_m")
# Out:
#                         Series_Title  Released_Year  Runtime      Genre  \
# 150                            Raazi           2018      138     Action
# 197                  Kurenai no buta           1992       94  Animation
# 251                Avengers: Endgame           2019      181     Action
# 211                         Lifeboat           1944       97      Drama
# 171  Who's Afraid of Virginia Woolf?           1966      131      Drama
# 100                           Avatar           2009      162     Action
# 134                 The Elephant Man           1980      124  Biography
# 105                   Love and Death           1975       85     Comedy
# 258                Tengoku to jigoku           1963      143      Crime
# 295                      Kumonosu-jô           1957      110      Drama
#
#      IMDB_Rating          Director               Star1  No_of_Votes  \
# 150          7.8     Meghna Gulzar          Alia Bhatt        25344
# ...

# %% [markdown]
# # `6) Get the average IMDb rating of all movies in the dataset.

# %%
df['IMDB_Rating'].mean()
# Out:
# np.float64(7.963333333333333)

# %% [markdown]
# # 7 Unique Genre in the datasets

# %%
df['Genre'].unique()
# Out:
# array(['Drama', 'Crime', 'Action', 'Biography', 'Comedy', 'Adventure',
#        'Film-Noir', 'Animation', 'Horror', 'Mystery', 'Fantasy',
#        'Western'], dtype=object)

# %% [markdown]
# ## get the total No of Miovies from the datseets

# %%
df.shape[0]
# Out:
# 300

# %% [markdown]
# # 11 Find the average gross for movies directed by a specific director, with an IMDb rating above 7.
# # Eg director : ‘Christopher Nolan’

# %%
df[df['Director']=="Christopher Nolan"]['Gros_in_m'].mean()
# Out:
# np.float64(345.3633333333334)

# %% [markdown]
# ## 12 Find the oldest movie in terms of release year with an IMDb rating greater than 8

# %%
temp=df.sort_values('Released_Year')
temp[temp['IMDB_Rating']>=8].head(20)
# Out:
#                           Series_Title  Released_Year  Runtime      Genre  \
# 115       Das Cabinet des Dr. Caligari           1920       76    Fantasy
# 148                         The Circus           1928       72     Comedy
# 9           La passion de Jeanne d'Arc           1928      110  Biography
# 122  M - Eine Stadt sucht einen Mörder           1931      117      Crime
# 132                       The Thin Man           1934       91     Comedy
# 33                  La Grande Illusion           1937      113      Drama
# 59                  Gone with the Wind           1939      238      Drama
# 82                 The Grapes of Wrath           1940      129      Drama
# 260         The Shop Around the Corner           1940       99     Comedy
# 10                          Casablanca           1942      102      Drama
# 277               Arsenic and Old Lace           1942      118     Comedy
# 72                    Double Indemnity           1944      107      Crime
# ...

# %%
df[['IMDB_Rating','Gros_in_m',"Runtime"]].corr()
# Out:
#              IMDB_Rating  Gros_in_m   Runtime
# IMDB_Rating     1.000000   0.038633  0.253895
# Gros_in_m       0.038633   1.000000 -0.031432
# Runtime         0.253895  -0.031432  1.000000

# %% [markdown]
# # 14 Find the top 5 stars who have appeared in the most movies.

# %%
top_5_actors=df['Star1'].value_counts().head(5).index
top_5_actors
# Out:
# Index(['Johnny Depp', 'Humphrey Bogart', 'Christian Bale', 'Leonardo DiCaprio',
#        'Al Pacino'],
#       dtype='object', name='Star1')

# %%
df[df['Star1'].isin(top_5_actors)]
# Out:
#                                           Series_Title  Released_Year  \
# 10                                          Casablanca           1942
# 24                                             Serpico           1973
# 32                                            Dead Man           1995
# 41   Pirates of the Caribbean: The Curse of the Bla...           2003
# 64                         What's Eating Gilbert Grape           1993
# 66                                             Sabrina           1954
# 69                             The Wolf of Wall Street           2013
# 76                    The Treasure of the Sierra Madre           1948
# 96                                     American Psycho           2000
# 103                                  Dog Day Afternoon           1975
# 106                     Fear and Loathing in Las Vegas           1998
# 109                                       The Revenant           2015
# ...

# %%
df  # 2011 , 2019 , 2000,2013
# Out:
#                            Series_Title  Released_Year  Runtime   Genre  \
# 0                             Chinatown           1974      130   Drama
# 1       The Girl with the Dragon Tattoo           2011      158   Crime
# 2                          Nueve reinas           2000      114   Crime
# 3    Close Encounters of the Third Kind           1977      138   Drama
# 4                                 Joker           2019      122   Crime
# ..                                  ...            ...      ...     ...
# 295                         Kumonosu-jô           1957      110   Drama
# 296                        Falling Down           1993      113  Action
# 297                The Royal Tenenbaums           2001      110  Comedy
# 298                     Midnight Cowboy           1969      113   Drama
# 299                         Kai po che!           2013      130   Drama
#
#      IMDB_Rating          Director             Star1  No_of_Votes  \
# ...

# %%
rel_year=[2011,2019,2000,2013]

df[df['Released_Year'].isin(rel_year)]
# Out:
#                          Series_Title  Released_Year  Runtime      Genre  \
# 1     The Girl with the Dragon Tattoo           2011      158      Crime
# 2                        Nueve reinas           2000      114      Crime
# 4                               Joker           2019      122      Crime
# 26            Jodaeiye Nader az Simin           2011      123      Drama
# 34                     Sound of Metal           2019      120      Drama
# 40                Requiem for a Dream           2000      102      Drama
# 44                        Jojo Rabbit           2019      108     Comedy
# 46                          Gully Boy           2019      154      Drama
# 63                   Fa yeung nin wah           2000       98      Drama
# 69            The Wolf of Wall Street           2013      180  Biography
# 78                Remember the Titans           2000      113  Biography
# 89                          Prisoners           2013      153      Crime
# ...

# %%
df[((df['Released_Year']==2011) | 
(df['Released_Year']==2019 ) | (df['Released_Year']==2000) | (df['Released_Year']==2013))]
# Out:
#                          Series_Title  Released_Year  Runtime      Genre  \
# 1     The Girl with the Dragon Tattoo           2011      158      Crime
# 2                        Nueve reinas           2000      114      Crime
# 4                               Joker           2019      122      Crime
# 26            Jodaeiye Nader az Simin           2011      123      Drama
# 34                     Sound of Metal           2019      120      Drama
# 40                Requiem for a Dream           2000      102      Drama
# 44                        Jojo Rabbit           2019      108     Comedy
# 46                          Gully Boy           2019      154      Drama
# 63                   Fa yeung nin wah           2000       98      Drama
# 69            The Wolf of Wall Street           2013      180  Biography
# 78                Remember the Titans           2000      113  Biography
# 89                          Prisoners           2013      153      Crime
# ...

# %% [markdown]
# ## 15 Get the average gross for movies with different genres, but only for movies with IMDb ratings
# ## greater than 7.

# %%
df[df['IMDB_Rating']>=8.5].groupby('Genre')['Gros_in_m'].mean()
# Out:
# Genre
# Action       227.8625
# Animation    216.4200
# Biography    440.9800
# Crime        135.7450
# Drama         37.1040
# Western        5.3200
# Name: Gros_in_m, dtype: float64

# %% [markdown]
# # 17 Get the number of movies with an IMDb rating greater than 8.5 for each genre.

# %%
df[df['IMDB_Rating']>=8.5]['Genre'].value_counts()
# Out:
# Genre
# Crime        8
# Drama        5
# Action       4
# Animation    2
# Western      1
# Biography    1
# Name: count, dtype: int64

# %%
df[df['IMDB_Rating']>=8.5].groupby('Genre')['Genre'].count()
# Out:
# Genre
# Action       4
# Animation    2
# Biography    1
# Crime        8
# Drama        5
# Western      1
# Name: Genre, dtype: int64

# %%
df[df['IMDB_Rating']>=8.5].groupby('Genre')['Director'].unique()
# Out:
# Genre
# Action       [Lana Wachowski, James Cameron, Christopher No...
# Animation                       [Roger Allers, Hayao Miyazaki]
# Biography                                        [Thomas Kail]
# Crime        [Todd Phillips, Jonathan Demme, Fernando Meire...
# Drama        [Michael Curtiz, Frank Capra, David Fincher, C...
# Western                                         [Sergio Leone]
# Name: Director, dtype: object

# %%
df[df['IMDB_Rating']>=8.5].groupby('Genre')['Director'].nunique()
# Out:
# Genre
# Action       4
# Animation    2
# Biography    1
# Crime        8
# Drama        5
# Western      1
# Name: Director, dtype: int64

# %%
df[df['IMDB_Rating']>=8.5].groupby('Genre').agg({"Director":['nunique','count']})
# Out:
#           Director
#            nunique count
# Genre
# Action           4     4
# Animation        2     2
# Biography        1     1
# Crime            8     8
# Drama            5     5
# Western          1     1

# %%
df.groupby('Genre').agg({"Director":['nunique','count']})
# Out:
#           Director
#            nunique count
# Genre
# Action          44    50
# Adventure       12    13
# Animation       21    29
# Biography       28    29
# Comedy          45    50
# Crime           33    37
# Drama           73    86
# Fantasy          1     1
# Film-Noir        1     1
# Horror           2     2
# Mystery          1     1
# Western          1     1

# %%
# 44	50

# %%
## Director : movies > 2

# %%
temps=df[df['Genre']=="Action"].groupby('Director')['Released_Year'].count()
dire_more_2=temps[temps>=2].index
dire_more_2
# Out:
# Index(['Christopher Nolan', 'Howard Hawks', 'James Cameron', 'Matthew Vaughn',
#        'Quentin Tarantino'],
#       dtype='object', name='Director')

# %%
df[df['Director'].isin(dire_more_2)].sort_values('Director')
# Out:
#                           Series_Title  Released_Year  Runtime   Genre  \
# 129                    The Dark Knight           2008      152  Action
# 144                       The Prestige           2006      130   Drama
# 190              The Dark Knight Rises           2012      164  Action
# 80   Scarface: The Shame of the Nation           1932       93  Action
# 131                   Bringing Up Baby           1938      102  Comedy
# 184                          Red River           1948      133  Action
# 100                             Avatar           2009      162  Action
# 104         Terminator 2: Judgment Day           1991      137  Action
# 284                     The Terminator           1984      107  Action
# 15                            Kick-Ass           2010      117  Action
# 16        Kingsman: The Secret Service           2014      129  Action
# 117                     Reservoir Dogs           1992       99   Crime
# ...

# %%
## finsd the

# %%
temp=df.groupby('Director')['Series_Title'].count()
dir_more_2=temp[temp>2].index
dir_more_2
# Out:
# Index(['Akira Kurosawa', 'Billy Wilder', 'Christopher Nolan', 'Clint Eastwood',
#        'David Fincher', 'David Lynch', 'Hayao Miyazaki', 'Howard Hawks',
#        'James Cameron', 'Krzysztof Kieslowski', 'Martin Scorsese',
#        'Pete Docter', 'Quentin Tarantino', 'Richard Linklater', 'Tim Burton',
#        'Wes Anderson', 'Woody Allen'],
#       dtype='object', name='Director')

# %%
filtred=df[df['Director'].isin(dir_more_2)]
filtred
# Out:
#                           Series_Title  Released_Year  Runtime      Genre  \
# 1      The Girl with the Dragon Tattoo           2011      158      Crime
# 17               Trois couleurs: Rouge           1994       99      Drama
# 31                  The King of Comedy           1982      109     Comedy
# 50                         Blue Velvet           1986      120      Drama
# 60                           Manhattan           1979       96     Comedy
# 66                             Sabrina           1954      113     Comedy
# 69             The Wolf of Wall Street           2013      180  Biography
# 72                    Double Indemnity           1944      107      Crime
# 80   Scarface: The Shame of the Nation           1932       93     Action
# 100                             Avatar           2009      162     Action
# 104         Terminator 2: Judgment Day           1991      137     Action
# 105                     Love and Death           1975       85     Comedy
# ...

# %%
filtred.groupby(['Director','Genre'])['Star1'].count()
# Out:
# Director              Genre
# Akira Kurosawa        Action       1
#                       Crime        1
#                       Drama        1
# Billy Wilder          Comedy       2
#                       Crime        1
#                       Drama        1
# Christopher Nolan     Action       2
#                       Drama        1
# Clint Eastwood        Drama        3
# David Fincher         Crime        2
#                       Drama        1
# David Lynch           Biography    1
#                       Drama        2
# Hayao Miyazaki        Animation    4
# Howard Hawks          Action       2
#                       Comedy       1
# James Cameron         Action       3
# Krzysztof Kieslowski  Drama        3
# Martin Scorsese       Biography    1
#                       Comedy       1
#                       Crime        1
# Pete Docter           Animation    3
# Quentin Tarantino     Action       2
#                       Comedy       1
# ...

# %% [markdown]
# ## load the datasets

# %%
df=pd.read_csv(r"tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [raw]
# pd.crosstab(
#     index,
#     columns,
#     values=None,
#     rownames=None,
#     colnames=None,
#     aggfunc=None,
#     margins: 'bool' = False,
#     margins_name: 'Hashable' = 'All',
#     dropna: 'bool' = True,
#     normalize: "bool | Literal[0, 1, 'all', 'index', 'columns']"

# %%
df[['sex','smoker']]
# Out:
#         sex smoker
# 0    Female     No
# 1      Male     No
# 2      Male     No
# 3      Male     No
# 4    Female     No
# ..      ...    ...
# 239    Male     No
# 240  Female    Yes
# 241    Male    Yes
# 242    Male     No
# 243  Female     No
#
# [244 rows x 2 columns]

# %%
df['sex']
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: sex, Length: 244, dtype: object

# %%
df['smoker']
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
# Name: smoker, Length: 244, dtype: object

# %%
pd.crosstab(index=df['sex'],columns=df['smoker'])
# Out:
# smoker  No  Yes
# sex
# Female  54   33
# Male    97   60

# %%
pd.crosstab(index=df['sex'],columns=df['smoker'],margins=True)
# Out:
# smoker   No  Yes  All
# sex
# Female   54   33   87
# Male     97   60  157
# All     151   93  244

# %%
pd.crosstab(index=df['sex'],columns=df['smoker'],margins=True,margins_name="total")
# Out:
# smoker   No  Yes  total
# sex
# Female   54   33     87
# Male     97   60    157
# total   151   93    244

# %%
pd.crosstab(index=df['sex'],columns=df['smoker'],normalize="columns")
# Out:
# smoker        No       Yes
# sex
# Female  0.357616  0.354839
# Male    0.642384  0.645161

# %%
pd.crosstab(index=df['sex'],columns=df['smoker'],normalize="columns")*100
# Out:
# smoker         No        Yes
# sex
# Female  35.761589  35.483871
# Male    64.238411  64.516129

# %%
pd.crosstab(index=df['sex'],columns=df['smoker'],normalize=1)*100
# Out:
# smoker         No        Yes
# sex
# Female  35.761589  35.483871
# Male    64.238411  64.516129

# %%
pd.crosstab(index=df['sex'],columns=df['smoker'],normalize=0)*100  # row wise
# Out:
# smoker         No        Yes
# sex
# Female  62.068966  37.931034
# Male    61.783439  38.216561

# %%
pd.crosstab(index=df['sex'],columns=df['smoker'],normalize="index")*100  # row wise
# Out:
# smoker         No        Yes
# sex
# Female  62.068966  37.931034
# Male    61.783439  38.216561

# %%
pd.crosstab(index=df['sex'],columns=df['smoker'],margins=True)
# Out:
# smoker   No  Yes  All
# sex
# Female   54   33   87
# Male     97   60  157
# All     151   93  244

# %%
(54/87)*100
# Out:
# 62.06896551724138

# %%
(33/87)*100
# Out:
# 37.93103448275862

# %%
54/151
# Out:
# 0.3576158940397351

# %%
97/151
# Out:
# 0.6423841059602649

# %%
normalize: "bool | Literal[0, 1, 'all', 'index', 'columns']"

# %%
pd.crosstab(index=df['sex'],columns=df['smoker'],margins=True)
# Out:
# smoker   No  Yes  All
# sex
# Female   54   33   87
# Male     97   60  157
# All     151   93  244

# %%
pd.crosstab(index=df['sex'],columns=df['smoker'],normalize="all")*100
# Out:
# smoker         No        Yes
# sex
# Female  22.131148  13.524590
# Male    39.754098  24.590164

# %%
pd.crosstab(index=df['sex'],columns=df['smoker'],margins=True)
# Out:
# smoker   No  Yes  All
# sex
# Female   54   33   87
# Male     97   60  157
# All     151   93  244

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
pd.crosstab(index=df['sex'],columns=df['smoker'],values=df['total_bill'], aggfunc="sum")
# Out:
# smoker       No      Yes
# sex
# Female   977.68   593.27
# Male    1919.75  1337.07

# %%
df[(df['sex']=="Female") & (df['smoker']=="No")]['total_bill'].sum()
# Out:
# np.float64(977.6800000000001)

# %%
pd.crosstab(index=df['sex'],columns=df['smoker'],values=df['total_bill'], aggfunc="sum",margins=True)
# Out:
# smoker       No      Yes      All
# sex
# Female   977.68   593.27  1570.95
# Male    1919.75  1337.07  3256.82
# All     2897.43  1930.34  4827.77

# %%
pd.crosstab(index=df['sex'],columns=df['smoker'],values=df['total_bill'], aggfunc="min",margins=True)
# Out:
# smoker    No   Yes   All
# sex
# Female  7.25  3.07  3.07
# Male    7.51  7.25  7.25
# All     7.25  3.07  3.07

# %%
pd.crosstab(index=df['sex'],columns=df['smoker'],values=df['total_bill'], aggfunc="mean",margins=True)
# Out:
# smoker         No        Yes        All
# sex
# Female  18.105185  17.977879  18.056897
# Male    19.791237  22.284500  20.744076
# All     19.188278  20.756344  19.785943

# %%
(18.105185+17.977879)/2
# Out:
# 18.041532

# %%
(19.188278	+20.756344+18.056897 + 20.744076 )/4
# Out:
# 19.68639875

# %%
pd.crosstab(index=df['sex'],columns=df['smoker'],values=df['total_bill'], aggfunc="mean",margins=True)
# Out:
# smoker         No        Yes        All
# sex
# Female  18.105185  17.977879  18.056897
# Male    19.791237  22.284500  20.744076
# All     19.188278  20.756344  19.785943

# %% [markdown]
# ## Pivot Table

# %% [raw]
# df.pivot_table(values=None,
#     index=None,
#     columns=None,
#     aggfunc: 'AggFuncType' = 'mean',
#     fill_value=None,
#     margins: 'bool' = False,
#     dropna: 'bool' = True,
#     margins_name: 'Level' = 'All',
#     observed: 'bool | lib.NoDefault' = <no_default>,
#     sort: 'bool' = True)

# %%
df.pivot_table(index="sex",columns="smoker",values="tip", aggfunc="sum")
# Out:
# smoker      No     Yes
# sex
# Female  149.77   96.74
# Male    302.00  183.07

# %%
df.pivot_table(index=["sex","time"],columns="smoker",values="tip", aggfunc="sum")
# Out:
# smoker             No     Yes
# sex    time
# Female Dinner   88.28   67.83
#        Lunch    61.49   28.91
# Male   Dinner  243.17  146.79
#        Lunch    58.83   36.28

# %%
df.pivot_table(index=["sex","time"],columns=["day","smoker"],values="tip", aggfunc="sum")
# Out:
# day             Fri            Sat            Sun          Thur
# smoker           No    Yes      No    Yes      No    Yes     No    Yes
# sex    time
# Female Dinner  3.25  10.80   35.42  43.03   46.61  14.00   3.00    NaN
#        Lunch   3.00   7.98     NaN    NaN     NaN    NaN  58.49  20.93
# Male   Dinner  5.00  16.23  104.21  77.74  133.96  52.82    NaN    NaN
#        Lunch    NaN   5.70     NaN    NaN     NaN    NaN  58.83  30.58

# %%
df[(df['day']=="Sat") & (df['sex']=="Female") & (df['time']=="Dinner")& (df['smoker']=="No")]['tip'].sum()
# Out:
# np.float64(35.42)

# %%
pd.pivot_table(df,index=["sex","time"],columns=["day","smoker"],values="tip", aggfunc="sum")
# Out:
# day             Fri            Sat            Sun          Thur
# smoker           No    Yes      No    Yes      No    Yes     No    Yes
# sex    time
# Female Dinner  3.25  10.80   35.42  43.03   46.61  14.00   3.00    NaN
#        Lunch   3.00   7.98     NaN    NaN     NaN    NaN  58.49  20.93
# Male   Dinner  5.00  16.23  104.21  77.74  133.96  52.82    NaN    NaN
#        Lunch    NaN   5.70     NaN    NaN     NaN    NaN  58.83  30.58

# %%
pd.crosstab(index=df['sex'],columns=df['smoker'],values=df['total_bill'], aggfunc="mean")

pd.pivot_table(df,index="sex",columns="smoker",values="tip", aggfunc="sum")

# %%
Parameters
----------
index : array-like, Series, or list of arrays/Series
    Values to group by in the rows.
columns : array-like, Series, or list of arrays/Series
    Values to group by in the columns.
values : array-like, optional
    Array of values to aggregate according to the factors.
    Requires `aggfunc` be specified.
rownames : sequence, default None
    If passed, must match number of row arrays passed.
colnames : sequence, default None
    If passed, must match number of column arrays passed.
aggfunc : function, optional
    If specified, requires `values` be specified as well.
margins : bool, default False
    Add row/column margins (subtotals).
margins_name : str, default 'All'
    Name of the row/column that will contain the totals
    when margins is True.
dropna : bool, default True
    Do not include columns whose entries are all NaN.
normalize : bool, {'all', 'index', 'columns'}, or {0,1}, default False
    Normalize by dividing all values by the sum of values.

    - If passed 'all' or `True`, will normalize over all values.
    - If passed 'index' will normalize over each row.
    - If passed 'columns' will normalize over each column.
    - If margins is `True`, will also normalize margin values.

Returns
-------
DataFrame
    Cross tabulation of the data.

See Also

# %% [raw]
# Parameters
# ----------
# data : DataFrame
#
# values : list-like or scalar, optional
#     Column or columns to aggregate.
#
# index : column, Grouper, array, or list of the previous
#     Keys to group by on the pivot table index. If a list is passed,
#     it can contain any of the other types (except list). If an array is
#     passed, it must be the same length as the data and will be used in
#     the same manner as column values.
#
# columns : column, Grouper, array, or list of the previous
#     Keys to group by on the pivot table column. If a list is passed,
#     it can contain any of the other types (except list). If an array is
#     passed, it must be the same length as the data and will be used in
#     the same manner as column values.
# aggfunc : function, list of functions, dict, default "mean"
#     If a list of functions is passed, the resulting pivot table will have
#     hierarchical columns whose top level are the function names
#     (inferred from the function objects themselves).
#     If a dict is passed, the key is column to aggregate and the value is
#     function or list of functions. If ``margin=True``, aggfunc will be
#     used to calculate the partial aggregates.
# fill_value : scalar, default None
#     Value to replace missing values with (in the resulting pivot table,
#     after aggregation).
# margins : bool, default False
#     If ``margins=True``, special ``All`` columns and rows
#     will be added with partial group aggregates across the categories
#     on the rows and columns.
# dropna : bool, default True
#     Do not include columns whose entries are all NaN. If True,
#     rows with a NaN value in any column will be omitted before
#     computing margins.
# margins_name : str, default 'All'
#     Name of the row / column that will contain the totals
#     when margins is True.
# observed : bool, default False
#     This only applies if any of the groupers are Categoricals.
#     If True: only show observed values for categorical groupers.
#     If False: show all values for categorical groupers.
#
#     .. deprecated:: 2.2.0
#
#         The default value of ``False`` is deprecated and will change to
#         ``True`` in a future version of pandas.
#
# sort : bool, default True
#     Specifies if the result should be sorted.
#
#     .. versionadded:: 1.3.0

# %% [markdown]
# ## iloc and loc

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Desktop\\New folder (4)'
