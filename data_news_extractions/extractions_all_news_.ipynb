# %% [markdown]
# # Extract Kantipur

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import time


options = Options()
driver = webdriver.Chrome(options=options)
driver.get("https://ekantipur.com/business")
time.sleep(3)

all_urls = []
for i in range(1, 5):
    try:
        path = f"/html/body/div[1]/div/div[{i}]/div/div[1]/h2/a"
        url = driver.find_element(By.XPATH, path).get_attribute("href")
        all_urls.append(url)
    
    except Exception as e:
        print(e)
        
news_data = []
for idx, url in enumerate(all_urls):
    try:
        driver.get(url)
        time.sleep(5)
        try:
            driver.find_element(By.XPATH,"/html/body/div[6]/div/div/div[2]/div/button").click()
            print("clicked")
        except Exception as e:
            print(e)
        time.sleep(2)
        title = driver.title
        news = driver.find_element(By.CLASS_NAME,"news-section-wrap-story").text
        news_data.append({"title": title,"news": news})

    except Exception as e:
        print(e)
driver.quit()
kantipur=pd.DataFrame(news_data)
# Out:
# clicked
# clicked
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[6]/div/div/div[2]/div/button"}
#   (Session info: chrome=148.0.7778.217); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x7ff7ce067de5+14895]
# 	chromedriver!GetHandleVerifier [0x7ff7ce067e50+14900]
# 	chromedriver!(No symbol) [0x7ff7cddcd5ad]
# 	chromedriver!(No symbol) [0x7ff7cde27822]
# 	chromedriver!(No symbol) [0x7ff7cde27b2c]
# 	chromedriver!(No symbol) [0x7ff7cde77d17]
# 	chromedriver!(No symbol) [0x7ff7cde7486f]
# 	chromedriver!(No symbol) [0x7ff7cde19df8]
# 	chromedriver!(No symbol) [0x7ff7cde1ace3]
# 	chromedriver!GetHandleVerifier [0x7ff7ce37cc49+3296f9]
# 	chromedriver!GetHandleVerifier [0x7ff7ce377375+323e25]
# 	chromedriver!GetHandleVerifier [0x7ff7ce39bc82+348732]
# ...

# %%
df
# Out:
#                                                title  \
# 0      सुनको मूल्य तोलाको २ हजारले बढ्यो - कान्तिपुर
# 1  फैलिँदै बर्डफ्लु : १० जिल्लामा ५ लाख १५ हजार प...
# 2  करका दर हेरफेर र बजेटपूर्व सूचना चुहाएको भन्दै...
#
#                                                 news
# 0  काठमाडौँ — नेपाली बजारमा आज सुन-चाँदीकै मूल्य ...
# 1  काठमाडौँ — सरकारले बर्डफ्लु प्रभावित क्षेत्रमा...
# 2

# %%
import pandas as pd

# %%
pd.DataFrame(news_data)
# Out:
#                                                title  \
# 0      सुनको मूल्य तोलाको २ हजारले बढ्यो - कान्तिपुर
# 1  फैलिँदै बर्डफ्लु : १० जिल्लामा ५ लाख १५ हजार प...
#
#                                                 news
# 0  काठमाडौँ — नेपाली बजारमा आज सुन-चाँदीकै मूल्य ...
# 1  काठमाडौँ — सरकारले बर्डफ्लु प्रभावित क्षेत्रमा...

# %% [markdown]
# ## Online khabar

# %%
# https://www.onlinekhabar.com/

# %%
# /html/body/div[8]/div[2]/section[11]/div/h2/a
# /html/body/div[8]/div[2]/section[12]/div/h2/a


# skip this button 
# /html/body/div[1]/div/div/div/div[2]/span



# ok18-single-post-content-wrap
# ok18-single-post-content-wrap

# %% [markdown]
# # ok news

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time

options = Options()
options.add_argument("--headless=new")
options.add_argument("--start-maximized")
options.add_argument("--window-size=1920,1080")
options.add_argument("--disable-gpu")
options.add_argument("--no-sandbox")

driver = webdriver.Chrome(options=options)
driver.get("https://www.onlinekhabar.com/")
time.sleep(10)

all_urls = []

for i in range(4, 7):
    try:
        path = f"/html/body/div[8]/div[2]/section[{i}]/div/h2/a"
        url = driver.find_element(By.XPATH, path).get_attribute("href")
        all_urls.append(url)
        print(url)

    except Exception as e:
        print(e)

news_data = []

for idx, url in enumerate(all_urls):
    try:
        driver.get(url)
        time.sleep(5)
        # close popup if exists
        try:
            driver.find_element(By.XPATH, "/html/body/div[1]/div/div/div/div[2]/span").click()
        except:
            pass
        time.sleep(2)
        title = driver.title
        news = driver.find_element(By.CLASS_NAME, "ok18-single-post-content-wrap").text
        news_data.append({"title": title,"news": news})
    except Exception as e:
        print(e)
driver.quit()
ok=pd.DataFrame(news_data)
ok['news']=ok['news'].str.replace("News Summary\nGenerated by OK AI. Editorially reviewed.\n","")
ok
# Out:
# https://www.onlinekhabar.com/2026/06/1950222/foreign-currency-can-be-sent-5-percent-more-than-the-specified-amount-for-studying-abroad
# https://www.onlinekhabar.com/2026/06/1950203/traffic-on-bp-highway-suspended-due-to-increased-floodwaters
# https://www.onlinekhabar.com/2026/06/1950163/mahavir-pun-will-take-charge-of-the-former-sports-ministry
#                                                title  \
# 0  विदेश अध्ययनका लागि तोकिएभन्दा ५ प्रतिशत धेरै ...
# 1  रोशीको बहाव बढेपछि बीपी राजमार्गमा सवारी सञ्चा...
# 2  साविकको खेलकुद मन्त्रालयमा हुनेछ महावीर पुनको ...
#
#                                                 news
# 0  नेपाल राष्ट्र बैंकले विदेशमा अध्ययन गर्न जाने ...
# 1  काभ्रेको रोशी खोलामा पानीको बहाव उच्च भएपछि सम...
# 2  नवनियुक्त विज्ञान, प्रविधि तथा नवप्रवर्तन मन्त...

# %%
ok=pd.DataFrame(news_data)
ok['news']=ok['news'].str.replace("News Summary\nGenerated by OK AI. Editorially reviewed.\n","")
ok
# Out:
#                                                title  \
# 0  विदेश अध्ययनका लागि तोकिएभन्दा ५ प्रतिशत धेरै ...
# 1  रोशीको बहाव बढेपछि बीपी राजमार्गमा सवारी सञ्चा...
# 2  साविकको खेलकुद मन्त्रालयमा हुनेछ महावीर पुनको ...
#
#                                                 news
# 0  नेपाल राष्ट्र बैंकले विदेशमा अध्ययन गर्न जाने ...
# 1  काभ्रेको रोशी खोलामा पानीको बहाव उच्च भएपछि सम...
# 2  नवनियुक्त विज्ञान, प्रविधि तथा नवप्रवर्तन मन्त...

# %%
ok['news'][2]
# Out:
# 'नवनियुक्त विज्ञान, प्रविधि तथा नवप्रवर्तन मन्त्री महावीर पुनले साविकको खेलकुद मन्त्रालयको भवनमा पदभार ग्रहण गर्ने भएका छन् ।\nनयाँ मन्त्रालय भएकाले हालसम्म निश्चित भवन तयार नभएकाले खेलकुद मन्त्रालयको भवन रोजिएको हो ।\nमन्त्रालयकी सहसचिव मोनिका झाका अनुसार सचिव प्रमिला बज्रचार्यको कार्यकक्ष पनि सोही भवनमा व्यवस्थापन गरिएको छ ।\n२६ जेठ, काठमाडौं । विज्ञान, प्रविधि तथा नवप्रवर्तन मन्त्रीको रूपमा सांसद महावीर पुनले पदभार ग्रहण गर्दैछन् ।\nनयाँ मन्त्रालय गठन भएकोले अहिलेसम्म यसको व्यवस्थापन भइसकेको छैन । यसअघि शिक्षा मन्त्रालय भित्रकै विज्ञान प्रविधि शाखाभित्र रहेर कामकाज चलिरहेको छ । त्यसैले मन्त्रालयको कुनै निश्चित भवन तयारी भइनसकेकाले उनले कता पदभार ग्रहण गर्छन् भन्ने आमचासो देखिन्छ ।\nविज्ञान, प्रविधि तथा नवप्रवर्तन मन्त्रालयकी सहसचिव मोनिका झाका अनुसार पुनले साविकको खेलकुद मन्त्रालयको भवनमा पदभार ग्रहण गर्नेछन् ।\nमन्त्रालयको कामकाज हालसम्म शिक्षा अन्तर्गत रहेको साविककै महाशाखाबाट चलिरहे पनि मन्त्रीलाई भने साविकको खेलकुद मन्त्रालयमा राखिनेछ ।\nकेही समयअघि सरुवा भएर यस मन्त्रालयमा आए
# ...

# %%
# /html/body/div[8]/div[2]/section[10]/div/h2/a
# /html/body/div[8]/div[2]/section[4]/div/h2/a

# %% [markdown]
# ## Bajar ko chirfar

# %%
options = Options()
options.add_argument("--headless=new")
options.add_argument("--start-maximized")
options.add_argument("--window-size=1920,1080")
options.add_argument("--disable-gpu")
options.add_argument("--no-sandbox")

driver = webdriver.Chrome(options=options)

driver.get("https://bajarkochirfar.com/latest/")
time.sleep(5)
urls = []

for i in range(1,5):
    try:
        path=f"/html/body/div[1]/section/div/div[2]/div[{i}]/article/a[1]"
        url=driver.find_element(By.XPATH,path).get_attribute("href")
        urls.append(url)
    except:
        pass

news_data=[]
for url in urls:
    try:
        driver.get(url)
        time.sleep(2)
        news =(driver.find_element(By.XPATH,
                "/html/body/div[1]/div[1]/div/div[1]/main/div/div[1]/article/div").text)
        news_data.append({"title":driver.title,"news":news})
    except:
        pass

bajar_ko_chirfaar=pd.DataFrame(news_data)

# %%
pd.DataFrame(news_data)
# Out:
#                                                title  \
# 0  चार पटक मन्त्रिपरिषद् बैठक बस्दा पनि भएन बोर्ड...
# 1  एक कम्पनीको आईपीओ डिम्याट खातामा जम्मा हुँदै, ...
# 2  सुधन गुरुङ आज फेरि गृहमन्त्री बन्दै | BAJARKO ...
# 3  समस्याग्रस्त कर्णाली डेभलपमेन्ट बैंकले बचतकर्त...
#
#                                                 news
# 0  नेपाल धितोपत्र बोर्ड (सेबोन) को अध्यक्ष नियुक्...
# 1  टक्सार पिखुवा खोला हाइड्रोपावर लिमिटेडले निष्क...
# 2  रास्वपा सांसद सुधन गुरुङ फेरि गृहमन्त्री बन्ने...
# 3  कर्णाली डेभलपमेन्ट बैंक लिमिटेडले हालसम्म बचतक...

# %% [markdown]
# ## nmepali paisa

# %%
import time
from selenium.webdriver.common.by import By


options = Options()
options.add_argument("--headless=new")
options.add_argument("--start-maximized")
options.add_argument("--window-size=1920,1080")
options.add_argument("--disable-gpu")
options.add_argument("--no-sandbox")


driver = webdriver.Chrome(options=options)
driver.get("https://nepalipaisa.com/news")
time.sleep(5)

urls = []
news_list = []

for i in range(1, 6):
    try:
        url = (driver.find_element(
            By.XPATH,
            f"//div//div[2]//div//div//div//div[1]//div//div[2]//div[{i}]//div//a"
        ).get_attribute("href"))
        urls.append(url)
        print(url)
    except Exception as e :
        print(e)

for url in urls:
    try:
        driver.get(url)
        time.sleep(2)

        news = driver.find_element(By.ID, "newsBody").text
        news_list.append({"title":driver.title,"news":news})
        
    except:
        continue

driver.quit()

nepali_paisa=pd.DataFrame(news_list)
# Out:
# https://nepalipaisa.com/news-detail/91657
# https://nepalipaisa.com/news-detail/91656
# https://nepalipaisa.com/news-detail/91655
# None
# https://nepalipaisa.com/news-detail/91653

# %%
# /html/body/section[1]/div/div/div[2]/div/div[2]/div/div/div/div[1]/div/div[2]/div[4]/div/a
# /html/body/section[1]/div/div/div[2]/div/div[2]/div/div/div/div[1]/div/div[2]/div[3]/div/a

# %%
pd.DataFrame(news_list)
# Out:
#                                                title  \
# 0  Nepali Paisa | 'जेडब्ल्यू म्यारियट होटल काठमाड...
# 1  Nepali Paisa | बजेटमा समेटिए १० सुरुङमार्ग, रक...
# 2  Nepali Paisa | सुधन गुरुङसँगै महावीर पुनले पनि...
# 3  Nepali Paisa | मन्त्रिपरिषद् बैठकले गर्‍यो चार...
#
#                                                 news
# 0  काठमाडौं: एमएस ग्रुप अन्तर्गतको कम्पनी क्यापिट...
# 1  काठमाडौं: सरकारले आगामी आर्थिक वर्ष २०८३-८४ मा...
# 2  काठमाडौं: प्रधानमन्त्री बालेन्द्र शाहले विज्ञा...
# 3  काठमाडौं: आज मंगलबार बसेको मन्त्रिपरिषद् बैठकल...

# %%
news_list
# Out:
# [{'title': "Nepali Paisa | 'जेडब्ल्यू म्यारियट होटल काठमाडौं भ्याली' २०३१ सम्ममा सञ्चालनमा आउने",
# ...

# %%
# /html/body/div[1]/section/div/div[2]/div[5]/article/a[1]
# /html/body/div[1]/section/div/div[2]/div[4]/article/a[2]

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Desktop\\New folder\\dat_news_multiple_sources'

# %%
merged=pd.concat([nepali_paisa,bajar_ko_chirfaar,ok,kantipur],ignore_index=True)
merged[["news"]]
