# %%
import requests

url = "https://app.smartwealthpro.com/api/GetMutualFundsDividend?_=1779341133688"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

print(response.status_code)

# RAW BYTES
print(response.content[:500])

# RAW TEXT
print(response.text[:500])
# Out:
# 200
# b'\r\n<!DOCTYPE html>\r\n<html>\r\n<head>\r\n    <meta charset="utf-8" />\r\n    <meta name="viewport" content="width=device-width" />\r\n    <link id="favicon" type="icon shortcut" media="icon" href="/Images/favicon.ico" rel="icon" />\r\n    <link href="/Content/admin.css" rel="stylesheet" />\r\n    <link href="/Content/bootstrap.css" rel="stylesheet" />\r\n    <link href="/AdminTemplate/icons/font-awesome/css/font-awesome.min.css" rel="stylesheet" />\r\n    <!--fonts-->\r\n    <link href="https://fonts.googleapis.com'
#
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width" />
#     <link id="favicon" type="icon shortcut" media="icon" href="/Images/favicon.ico" rel="icon" />
#     <link href="/Content/admin.css" rel="stylesheet" />
#     <link href="/Content/bootstrap.css" rel="stylesheet" />
#     <link href="/AdminTemplate/icons/font-awesome/css/font-awesome.min.css" rel="stylesheet" />
#     <!--fonts-->
# ...

# %%
data = json.loads(text)

df = pd.DataFrame(data)

print(df.head())

# %%
import requests
import pandas as pd

url ="https://app.smartwealthpro.com/api/GetMutualFundsDividend?_=1779341133688"

headers = {
    "User-Agent": "Mozilla/5.0",
    "Cookie": "PASTE_BROWSER_COOKIES_HERE"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width" />
#     <link id="favicon" type="icon shortcut" media="icon" href="/Images/favicon.ico" rel="icon" />
#     <link href="/Content/admin.css" rel="stylesheet" />
#     <link href="/Content/bootstrap.css" rel="stylesheet" />
#     <link href="/AdminTemplate/icons/font-awesome/css/font-awesome.min.css" rel="stylesheet" />
#     <!--fonts-->
#     <link href="https://fonts.googleapis.com/css?family=Open+Sans" rel="stylesheet">
#     <link href="https://fonts.googleapis.com/css?family=Maven+Pro" rel="stylesheet">
#     <link href="/ClientTemplate/css/style.css" rel="stylesheet" />
#     <link href="/ClientTemplate/css/jquery-steps.css" rel="stylesheet">
#     <link href="/ClientTemplate/css/newcss.css" rel="stylesheet" />
#     <link href="/Content/impromptu.css" rel="stylesheet" />
#     <link href="/admintemplate/css/button-process.css" rel="stylesheet" />
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# =========================================================
# LOGIN PAGE
# =========================================================

login_url = "https://app.smartwealthpro.com/Account/Login"

# =========================================================
# API URL
# =========================================================

api_url = "https://app.smartwealthpro.com/api/GetMutualFundsDividend"


USERNAME = "muskasturid@gmail.com"
PASSWORD = "Nep@l2053"

# =========================================================
# SESSION
# =========================================================

session = requests.Session()

# =========================================================
# HEADERS
# =========================================================

headers = {
    "User-Agent": "Mozilla/5.0",
    "Referer": login_url
}

# =========================================================
# STEP 1: OPEN LOGIN PAGE
# =========================================================

response = session.get(login_url, headers=headers)

print("LOGIN PAGE STATUS:", response.status_code)

# =========================================================
# STEP 2: PARSE CSRF TOKEN
# =========================================================

soup = BeautifulSoup(response.text, "html.parser")

token = soup.find(
    "input",
    {"name": "__RequestVerificationToken"}
)["value"]

print("TOKEN FOUND")

# =========================================================
# STEP 3: LOGIN PAYLOAD
# =========================================================

payload = {
    "__RequestVerificationToken": token,
    "UserName": USERNAME,
    "Password": PASSWORD,
    "RememberMe": "false"
}

# =========================================================
# STEP 4: LOGIN REQUEST
# =========================================================

login_response = session.post(
    login_url,
    data=payload,
    headers=headers
)

print("LOGIN STATUS:", login_response.status_code)

# =========================================================
# CHECK LOGIN SUCCESS
# =========================================================

if "Log in" in login_response.text:
    print("LOGIN FAILED")
else:
    print("LOGIN SUCCESS")

# =========================================================
# STEP 5: ACCESS API
# =========================================================

api_headers = {
    "User-Agent": "Mozilla/5.0",
    "Accept": "application/json, text/plain, */*",
    "Referer": "https://app.smartwealthpro.com/"
}

api_response = session.get(
    api_url,
    headers=api_headers
)

print("API STATUS:", api_response.status_code)

# =========================================================
# PRINT RESPONSE
# =========================================================

print(api_response.text[:1000])

# =========================================================
# CONVERT TO JSON
# =========================================================

try:

    data = api_response.json()

    print("JSON SUCCESS")

    # =====================================================
    # DATAFRAME
    # =====================================================

    df = pd.DataFrame(data)

    print(df.head())

    # =====================================================
    # SAVE CSV
    # =====================================================

    # df.to_csv("mutual_funds_dividend.csv", index=False)

    print("CSV SAVED")

except Exception as e:

    print("JSON FAILED")
    print(e)

    with open("api_response.html", "w", encoding="utf-8") as f:
        f.write(api_response.text)

    print("RAW RESPONSE SAVED")
# Out:
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# ...

# %%
df
# Out:
#                                  companyName  companyId stockSymbol  \
# 0              Citizens Super 30 Mutual Fund        885       C30MF
# 1                     Citizens Mutual Fund 2        184        CMF2
# 2                  Citizens Sadabahar Yojana       1082        CSBY
# 3                   Citizens Santulit Yojana       1096         CSY
# 4   NIC Asia Equity Linked Investment Scheme       1087        ELIS
# ..                                       ...        ...         ...
# 62   Siddhartha Investment Growth Scheme - 2        199       SIGS2
# 63     Siddhartha Investment Growth Scheme-3        878       SIGS3
# 64                     Sanima Large Cap Fund        629        SLCF
# 65                          Subha Laxmi Kosh        821         SLK
# 66   Siddhartha Systematic Investment Scheme        747        SSIS
#
#     pricePercentChange launchDateAD launchDateBS  dividend distributionDateAD  \
# 0                 0.82   2023-04-19   2080-01-06     12.75
# ...

# %% [markdown]
# # Extract all the datas

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

login_url = "https://app.smartwealthpro.com/Account/Login"

api_url = "https://app.smartwealthpro.com/api/GetMutualFundsDividend"


USERNAME = "muskasturid@gmail.com"
PASSWORD = "Nep@l2053"

session = requests.Session()

headers = {
    "User-Agent": "Mozilla/5.0",
    "Referer": login_url
}

response = session.get(login_url, headers=headers)

print("LOGIN PAGE STATUS:", response.status_code)

soup = BeautifulSoup(response.text, "html.parser")

token = soup.find(
    "input",
    {"name": "__RequestVerificationToken"}
)["value"]

print("TOKEN FOUND")

payload = {
    "__RequestVerificationToken": token,
    "UserName": USERNAME,
    "Password": PASSWORD,
    "RememberMe": "false"
}

login_response = session.post(
    login_url,
    data=payload,
    headers=headers
)

print("LOGIN STATUS:", login_response.status_code)

# CHECK LOGIN SUCCESS

if "Log in" in login_response.text:
    print("LOGIN FAILED")
else:
    print("LOGIN SUCCESS")


# STEP 5: ACCESS API
api_headers = {
    "User-Agent": "Mozilla/5.0",
    "Accept": "application/json, text/plain, */*",
    "Referer": "https://app.smartwealthpro.com/"
}

api_response = session.get(
    api_url,
    headers=api_headers
)

print("API STATUS:", api_response.status_code)

# PRINT RESPONSE
# print(api_response.text[:1000])


# CONVERT TO JSON

try:

    data = api_response.json()
    print("JSON SUCCESS")
    # DATAFRAME
    df = pd.DataFrame(data)

    print(df.head())

    # SAVE CSV
    # df.to_csv("mutual_funds_dividend.csv", index=False)

    print("CSV SAVED")

except Exception as e:

    print("JSON FAILED")
    print(e)

    with open("api_response.html", "w", encoding="utf-8") as f:
        f.write(api_response.text)

    print("RAW RESPONSE SAVED")

# %% [markdown]
# ## extract all the urls

# %%
# https://app.smartwealthpro.com/api/GetMutualFundsDividend?_=1779341133688

# %%
## Closed ended

C30MF
# https://app.smartwealthpro.com/api/GetLiveCommentaryTicker
# https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779343389934
# https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779343389935
# https://app.smartwealthpro.com/api/GetAutoCompleteCompanies
# https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=885&_=1779343389937
# https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=885&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779343389938
# https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=885&itemsCount=10&_=1779343389939
# https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=885&_=1779343389940
# https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=885&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779343389941
#

# %% [markdown]
# # Gnereta e afunction to ecxtract tge data and extract all the compoanys datasets

# %%
urls = [
    "https://app.smartwealthpro.com/api/GetLiveCommentaryTicker",
    "https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779343389934",
    "https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779343389935",
    "https://app.smartwealthpro.com/api/GetAutoCompleteCompanies",
    "https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=885&_=1779343389937",
    "https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=885&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779343389938",
    "https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=885&itemsCount=10&_=1779343389939",
    "https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=885&_=1779343389940",
    "https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=885&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779343389941"
]

urls
# Out:
# ['https://app.smartwealthpro.com/api/GetLiveCommentaryTicker',
#  'https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779343389934',
#  'https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779343389935',
#  'https://app.smartwealthpro.com/api/GetAutoCompleteCompanies',
#  'https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=885&_=1779343389937',
#  'https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=885&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779343389938',
#  'https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=885&itemsCount=10&_=1779343389939',
#  'https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=885&_=1779343389940',
# ...

# %%
from urllib.parse import urlparse

endpoint_names = [
    urlparse(url).path.split("/api/")[-1]
    for url in urls
]

print(len(endpoint_names))
print(len(urls))
# Out:
# 9
# 9

# %%
def fetch_api_datadset(urls,end_points):
    login_url = "https://app.smartwealthpro.com/Account/Login"
    api_url = urls
    USERNAME = "muskasturid@gmail.com"
    PASSWORD = "Nep@l2053"
    session = requests.Session()
    headers = {
        "User-Agent": "Mozilla/5.0",
        "Referer": login_url
    }
    response = session.get(login_url, headers=headers)
    print("LOGIN PAGE STATUS:", response.status_code)
    soup = BeautifulSoup(response.text, "html.parser")
    token = soup.find(
        "input",
        {"name": "__RequestVerificationToken"}
    )["value"]
    
    print("TOKEN FOUND")
    payload = {
        "__RequestVerificationToken": token,
        "UserName": USERNAME,
        "Password": PASSWORD,
        "RememberMe": "false"
    }
    login_response = session.post(
        login_url,
        data=payload,
        headers=headers
    )
    print("LOGIN STATUS:", login_response.status_code)
    if "Log in" in login_response.text:
        print("LOGIN FAILED")
    else:
        print("LOGIN SUCCESS")
    
    # STEP 5: ACCESS API
    api_headers = {
        "User-Agent": "Mozilla/5.0",
        "Accept": "application/json, text/plain, */*",
        "Referer": "https://app.smartwealthpro.com/"
    }
    api_response = session.get(
        api_url,
        headers=api_headers
    )
    print("API STATUS:", api_response.status_code)
    try:
    
        data = api_response.json()
        print("JSON SUCCESS")
        df = pd.DataFrame(data)
        df.to_csv(f"C:\\Users\\HP\\Desktop\\data_extractions\\extraced_datasets\\data_fetch_of_all_comoany\\all_final_datasets\\company_\\GBIMESY2\\{end_points}.csv", index=False)
    except:
        pass

# %%
for i in range(len(urls)):
    fetch_api_datadset(urls[i],endpoint_names[i])
    print("exctract all the dcatasdets sucessfully ")
# Out:
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# ...

# %% [markdown]
# ## Extract the API dtaa of the another conmpany

# %%
### CMF2

# https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=184&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779344767314
# https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=184&_=1779344767313
# https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=184&itemsCount=10&_=1779344767312
# https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=184&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779344767311
# https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=184&_=1779344767310
# https://app.smartwealthpro.com/api/GetAutoCompleteCompanies
# https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779344767308
# https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779344767307
# https://app.smartwealthpro.com/api/GetLiveCommentaryTicker

# %%
urls_cmf2= [
    "https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=184&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779344767314",
    "https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=184&_=1779344767313",
    "https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=184&itemsCount=10&_=1779344767312",
    "https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=184&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779344767311",
    "https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=184&_=1779344767310",
    "https://app.smartwealthpro.com/api/GetAutoCompleteCompanies",
    "https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779344767308",
    "https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779344767307",
    "https://app.smartwealthpro.com/api/GetLiveCommentaryTicker"
]
urls_cmf2
# Out:
# ['https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=184&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779344767314',
#  'https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=184&_=1779344767313',
#  'https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=184&itemsCount=10&_=1779344767312',
#  'https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=184&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779344767311',
#  'https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=184&_=1779344767310',
#  'https://app.smartwealthpro.com/api/GetAutoCompleteCompanies',
#  'https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779344767308',
#  'https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779344767307',
# ...

# %%
endpoint_names = [
    urlparse(url).path.split("/api/")[-1]
    for url in urls_cmf2
]
endpoint_names
# Out:
# ['GetMutualFundNavComparision',
#  'GetMutualFundAssetsAllocation',
#  'GetMutualFundStockHoldings',
#  'GetMutualFundFinancials',
#  'GetStockDataForChart',
#  'GetAutoCompleteCompanies',
#  'GetNotificationsForUser',
#  'GetPortfolioSectorAndCompany',
#  'GetLiveCommentaryTicker']

# %%
for i in range(len(urls_cmf2)):
    fetch_api_datadset(urls_cmf2[i],endpoint_names[i])
    print("exctract all the dcatasdets sucessfully ")
# Out:
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# ...

# %%
len(urls_cmf2)
# Out:
# 9

# %%
len(endpoint_names)
# Out:
# 9

# %%
urls_cmf2
# Out:
# ['https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=184&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779344767314',
#  'https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=184&_=1779344767313',
#  'https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=184&itemsCount=10&_=1779344767312',
#  'https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=184&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779344767311',
#  'https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=184&_=1779344767310',
#  'https://app.smartwealthpro.com/api/GetAutoCompleteCompanies',
#  'https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779344767308',
#  'https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779344767307',
# ...

# %%
# csy

# https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=1096&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779346054171
# https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=1096&_=1779346054170
# https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=1096&itemsCount=10&_=1779346054169
# https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=1096&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779346054168
# https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=1096&_=1779346054167
# https://app.smartwealthpro.com/api/GetAutoCompleteCompanies
# https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779346054165
# https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779346054164
# https://app.smartwealthpro.com/api/GetLiveCommentaryTicker

# %%
CSY_links = [
    "https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=1096&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779346054171",
    "https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=1096&_=1779346054170",
    "https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=1096&itemsCount=10&_=1779346054169",
    "https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=1096&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779346054168",
    "https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=1096&_=1779346054167",
    "https://app.smartwealthpro.com/api/GetAutoCompleteCompanies",
    "https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779346054165",
    "https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779346054164",
    "https://app.smartwealthpro.com/api/GetLiveCommentaryTicker"
]

CSY_links
# Out:
# ['https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=1096&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779346054171',
#  'https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=1096&_=1779346054170',
#  'https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=1096&itemsCount=10&_=1779346054169',
#  'https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=1096&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779346054168',
#  'https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=1096&_=1779346054167',
#  'https://app.smartwealthpro.com/api/GetAutoCompleteCompanies',
#  'https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779346054165',
#  'https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779346054164',
# ...

# %%
endpoint_csys = [
    urlparse(url).path.split("/api/")[-1]
    for url in CSY_links 
]
endpoint_csys
# Out:
# ['GetMutualFundNavComparision',
#  'GetMutualFundAssetsAllocation',
#  'GetMutualFundStockHoldings',
#  'GetMutualFundFinancials',
#  'GetStockDataForChart',
#  'GetAutoCompleteCompanies',
#  'GetNotificationsForUser',
#  'GetPortfolioSectorAndCompany',
#  'GetLiveCommentaryTicker']

# %%
for i in range(len(urls_cmf2)):
    fetch_api_datadset(CSY_links [i],endpoint_csys[i])
    print("exctract all the dcatasdets sucessfully ")
# Out:
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# ...

# %% [markdown]
# ## GBIMESY2

# %%
# https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=1092&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779346722122
# https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=1092&_=1779346722121
# https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=1092&itemsCount=10&_=1779346722120
# https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=1092&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779346722119
# https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=1092&_=1779346722118
# https://app.smartwealthpro.com/api/GetAutoCompleteCompanies
# https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779346722116
# https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779346722115
# https://app.smartwealthpro.com/api/GetLiveCommentaryTicker

# %%
GBIMESY2 = [
    "https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=1092&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779346722122",
    "https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=1092&_=1779346722121",
    "https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=1092&itemsCount=10&_=1779346722120",
    "https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=1092&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779346722119",
    "https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=1092&_=1779346722118",
    "https://app.smartwealthpro.com/api/GetAutoCompleteCompanies",
    "https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779346722116",
    "https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779346722115",
    "https://app.smartwealthpro.com/api/GetLiveCommentaryTicker"
]
GBIMESY2
# Out:
# ['https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=1092&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779346722122',
#  'https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=1092&_=1779346722121',
#  'https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=1092&itemsCount=10&_=1779346722120',
#  'https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=1092&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779346722119',
#  'https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=1092&_=1779346722118',
#  'https://app.smartwealthpro.com/api/GetAutoCompleteCompanies',
#  'https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779346722116',
#  'https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779346722115',
# ...

# %%
endpoint_GBIMESY2 = [
    urlparse(url).path.split("/api/")[-1]
    for url in GBIMESY2 
]
endpoint_GBIMESY2
# Out:
# ['GetMutualFundNavComparision',
#  'GetMutualFundAssetsAllocation',
#  'GetMutualFundStockHoldings',
#  'GetMutualFundFinancials',
#  'GetStockDataForChart',
#  'GetAutoCompleteCompanies',
#  'GetNotificationsForUser',
#  'GetPortfolioSectorAndCompany',
#  'GetLiveCommentaryTicker']

# %%
for i in range(len(GBIMESY2)):
    fetch_api_datadset(GBIMESY2[i],endpoint_GBIMESY2[i])
    print("exctract all the dcatasdets sucessfully ")
# Out:
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# exctract all the dcatasdets sucessfully
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# ...

# %% [markdown]
# ## GIBF1

# %%
# https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=815&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779347340303
# https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=815&_=1779347340302
# https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=815&itemsCount=10&_=1779347340301
# https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=815&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779347340300
# https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=815&_=1779347340299
# https://app.smartwealthpro.com/api/GetAutoCompleteCompanies
# https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779347340297
# https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779347340296
# https://app.smartwealthpro.com/api/GetLiveCommentaryTicker

# %%
GIBF1 = [
    "https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=815&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779347340303",
    "https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=815&_=1779347340302",
    "https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=815&itemsCount=10&_=1779347340301",
    "https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=815&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779347340300",
    "https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=815&_=1779347340299",
    "https://app.smartwealthpro.com/api/GetAutoCompleteCompanies",
    "https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779347340297",
    "https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779347340296",
    "https://app.smartwealthpro.com/api/GetLiveCommentaryTicker"
]
GIBF1[:3]
# Out:
# ['https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=815&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779347340303',
#  'https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=815&_=1779347340302',
#  'https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=815&itemsCount=10&_=1779347340301']

# %%
endpoint_GIBF1 = [
    urlparse(url).path.split("/api/")[-1]
    for url in GIBF1
]
endpoint_GIBF1
# Out:
# ['GetMutualFundNavComparision',
#  'GetMutualFundAssetsAllocation',
#  'GetMutualFundStockHoldings',
#  'GetMutualFundFinancials',
#  'GetStockDataForChart',
#  'GetAutoCompleteCompanies',
#  'GetNotificationsForUser',
#  'GetPortfolioSectorAndCompany',
#  'GetLiveCommentaryTicker']

# %%
def fetch_api_datadset(urls,end_points,folder_name):
    login_url = "https://app.smartwealthpro.com/Account/Login"
    api_url = urls
    USERNAME = "muskasturid@gmail.com"
    PASSWORD = "Nep@l2053"
    session = requests.Session()
    headers = {
        "User-Agent": "Mozilla/5.0",
        "Referer": login_url
    }
    response = session.get(login_url, headers=headers)
    print("LOGIN PAGE STATUS:", response.status_code)
    soup = BeautifulSoup(response.text, "html.parser")
    token = soup.find(
        "input",
        {"name": "__RequestVerificationToken"}
    )["value"]
    
    print("TOKEN FOUND")
    payload = {
        "__RequestVerificationToken": token,
        "UserName": USERNAME,
        "Password": PASSWORD,
        "RememberMe": "false"
    }
    login_response = session.post(
        login_url,
        data=payload,
        headers=headers
    )
    print("LOGIN STATUS:", login_response.status_code)
    if "Log in" in login_response.text:
        print("LOGIN FAILED")
    else:
        print("LOGIN SUCCESS")
    
    # STEP 5: ACCESS API
    api_headers = {
        "User-Agent": "Mozilla/5.0",
        "Accept": "application/json, text/plain, */*",
        "Referer": "https://app.smartwealthpro.com/"
    }
    api_response = session.get(
        api_url,
        headers=api_headers
    )
    print("API STATUS:", api_response.status_code)
    try:
    
        data = api_response.json()
        print("JSON SUCCESS")
        df = pd.DataFrame(data)
        df.to_csv(f"C:\\Users\\HP\\Desktop\\data_extractions\\extraced_datasets\\data_fetch_of_all_comoany\\all_final_datasets\\company_\\{folder_name}\\{end_points}.csv", index=False)
    except:
        pass

# %%
for i in range(len(GIBF1)):
    fetch_api_datadset(GIBF1[i],endpoint_GIBF1[i],"GIBF1")
# Out:
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS

# %% [markdown]
# ## GSY

# %%
# https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=1049&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779348018674
# https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=1049&_=1779348018673
# https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=1049&itemsCount=10&_=1779348018672
# https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=1049&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779348018671
# https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=1049&_=1779348018670
# https://app.smartwealthpro.com/api/GetAutoCompleteCompanies
# https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779348018668
# https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779348018667
# https://app.smartwealthpro.com/api/GetLiveCommentaryTicker

# %%
GSY_urls = [
    "https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=1049&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779348018674",
    "https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=1049&_=1779348018673",
    "https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=1049&itemsCount=10&_=1779348018672",
    "https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=1049&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779348018671",
    "https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=1049&_=1779348018670",
    "https://app.smartwealthpro.com/api/GetAutoCompleteCompanies",
    "https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779348018668",
    "https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779348018667",
    "https://app.smartwealthpro.com/api/GetLiveCommentaryTicker"
]
GSY_urls[:5]
# Out:
# ['https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=1049&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779348018674',
#  'https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=1049&_=1779348018673',
#  'https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=1049&itemsCount=10&_=1779348018672',
#  'https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=1049&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779348018671',
#  'https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=1049&_=1779348018670']

# %%
endpoint_GSY = [
    urlparse(url).path.split("/api/")[-1]
    for url in GSY_urls
]
endpoint_GSY
# Out:
# ['GetMutualFundNavComparision',
#  'GetMutualFundAssetsAllocation',
#  'GetMutualFundStockHoldings',
#  'GetMutualFundFinancials',
#  'GetStockDataForChart',
#  'GetAutoCompleteCompanies',
#  'GetNotificationsForUser',
#  'GetPortfolioSectorAndCompany',
#  'GetLiveCommentaryTicker']

# %%
for i in range(len(GIBF1)):
    fetch_api_datadset(GSY_urls[i],endpoint_GSY[i],"GSY")
# Out:
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS

# %% [markdown]
# # H8020

# %%
# urls

# https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=935&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779348436695
# https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=935&_=1779348436694
# https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=935&itemsCount=10&_=1779348436693
# https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=935&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779348436692
# https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=935&_=1779348436691
# https://app.smartwealthpro.com/api/GetAutoCompleteCompanies
# https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779348436689
# https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779348436688
# https://app.smartwealthpro.com/api/GetLiveCommentaryTicker

# %%
H8020_urls = [
    "https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=935&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779348436695",
    "https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=935&_=1779348436694",
    "https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=935&itemsCount=10&_=1779348436693",
    "https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=935&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779348436692",
    "https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=935&_=1779348436691",
    "https://app.smartwealthpro.com/api/GetAutoCompleteCompanies",
    "https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779348436689",
    "https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779348436688",
    "https://app.smartwealthpro.com/api/GetLiveCommentaryTicker"
]

# %%
H8020_end_points = [
    urlparse(url).path.split("/api/")[-1]
    for url in H8020_urls
]
H8020_end_points
# Out:
# ['GetMutualFundNavComparision',
#  'GetMutualFundAssetsAllocation',
#  'GetMutualFundStockHoldings',
#  'GetMutualFundFinancials',
#  'GetStockDataForChart',
#  'GetAutoCompleteCompanies',
#  'GetNotificationsForUser',
#  'GetPortfolioSectorAndCompany',
#  'GetLiveCommentaryTicker']

# %%
for i in range(len(GIBF1)):
    fetch_api_datadset(H8020_urls[i],H8020_end_points[i],"H8020")
# Out:
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS
# LOGIN PAGE STATUS: 200
# TOKEN FOUND
# LOGIN STATUS: 200
# LOGIN SUCCESS
# API STATUS: 200
# JSON SUCCESS

# %% [markdown]
# # HLICF

# %%
# https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=1091&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779348856336
# https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=1091&_=1779348856335
# https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=1091&itemsCount=10&_=1779348856334
# https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=1091&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779348856333
# https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=1091&_=1779348856332
# https://app.smartwealthpro.com/api/GetAutoCompleteCompanies
# https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779348856330
# https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779348856329
# https://app.smartwealthpro.com/api/GetLiveCommentaryTicker

# %%
urls_HLICF = [
    "https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=1091&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779348856336",
    "https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=1091&_=1779348856335",
    "https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=1091&itemsCount=10&_=1779348856334",
    "https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=1091&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779348856333",
    "https://app.smartwealthpro.com/api/GetStockDataForChart?companyId=1091&_=1779348856332",
    "https://app.smartwealthpro.com/api/GetAutoCompleteCompanies",
    "https://app.smartwealthpro.com/api/GetNotificationsForUser?_=1779348856330",
    "https://app.smartwealthpro.com/api/GetPortfolioSectorAndCompany?pageNo=1&itemsPerPage=9999&pagePerDisplay=10&_=1779348856329",
    "https://app.smartwealthpro.com/api/GetLiveCommentaryTicker"
]
urls_HLICF[:5]
# Out:
# ['https://app.smartwealthpro.com/api/GetMutualFundNavComparision?companyId=1091&companies=&fundManagerId=0&sortAsc=true&sortBy=Stock%20Symbol&reportType=peer-comparison&_=1779348856336',
#  'https://app.smartwealthpro.com/api/GetMutualFundAssetsAllocation?companyId=1091&_=1779348856335',
#  'https://app.smartwealthpro.com/api/GetMutualFundStockHoldings?companyId=1091&itemsCount=10&_=1779348856334',
#  'https://app.smartwealthpro.com/api/GetMutualFundFinancials?companyId=1091&reportType=&timeline=Monthly&period=&nature=company&dataSampleCount=1&dataPrecision=1&_=1779348856333',
#  'https://app.smartwealthpro.com/api/GetStockDataForChart?companyId