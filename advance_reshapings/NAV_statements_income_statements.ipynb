# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\HP\Desktop\data_extractions\extraced_datasets\open_ended.csv")

# %% [markdown]
# # open ended

# %%
from selenium import webdriver

driver = webdriver.Chrome()
from selenium.webdriver.common.by import By
driver.get("https://app.smartwealthpro.com/MutualFund/Overview")

# %%
# /html/body/div[6]/div/div/div/div/div[2]/div/div[2]/div/div/div/div/div[2]/div/table/tbody/tr[44]/td[1]/a[1]
from selenium.webdriver.common.by import By

closed_ended=[]

for i in range(1,45):
    url_links=driver.find_element(By.XPATH,f"/html/body/div[6]/div/div/div/div/div[2]/div/div[2]/div/div/div/div/div[2]/div/table/tbody/tr[{i}]/td[1]/a[1]").get_attribute("href")
    closed_ended.append(url_links)

# %%
open_ended=[]

for i in range(1,12):
    url_links=driver.find_element(By.XPATH,f"/html/body/div[6]/div/div/div/div/div[2]/div/div[2]/div/div/div/div/div[2]/div/table/tbody/tr[{i}]/td[1]/a").get_attribute("href")
    open_ended.append(url_links)

# %%
matured=[]
for i in range(1,11):
    # /html/body/div[6]/div/div/div/div/div[2]/div/div[2]/div/div/div/div/div[2]/div/table/tbody/tr[9]/td[1]/a
    url_links=driver.find_element(By.XPATH,f"/html/body/div[6]/div/div/div/div/div[2]/div/div[2]/div/div/div/div/div[2]/div/table/tbody/tr[{i}]/td[1]/a").get_attribute("href")
    matured.append(url_links)

# %%
open_ended
# Out:
# ['https://app.smartwealthpro.com/Company/Overview/Citizens-Super-30-Mutual-Fund/C30MF?c=885',
#  'https://app.smartwealthpro.com/Company/Overview/Citizens-Mutual-Fund-2/CMF2?c=184',
#  'https://app.smartwealthpro.com/Company/Overview/Citizens-Santulit-Yojana/CSY?c=1096',
#  'https://app.smartwealthpro.com/Company/Overview/Global-IME-Sammunat-Yojana2/GBIMESY2?c=1092',
#  'https://app.smartwealthpro.com/Company/Overview/Global-IME-Balanced-Fund--1/GIBF1?c=815',
#  'https://app.smartwealthpro.com/Company/Overview/Garima-Samriddhi-Yojana/GSY?c=1049',
#  'https://app.smartwealthpro.com/Company/Overview/Himalayan-8020/H8020?c=935',
#  'https://app.smartwealthpro.com/Company/Overview/HLI-Large-Cap-Fund/HLICF?c=1091',
#  'https://app.smartwealthpro.com/Company/Overview/Kumari-Dhanabriddhi-Yojana/KDBY?c=797',
#  'https://app.smartwealthpro.com/Company/Overview/Kumari-Equity-Fund/KEF?c=729',
#  'https://app.smartwealthpro.com/Company/Overview/Kumari-Sabal-Yojana/KSY?c=956']

# %%
closed_ended
# Out:
# ['https://app.smartwealthpro.com/Company/Overview/Citizens-Super-30-Mutual-Fund/C30MF?c=885',
#  'https://app.smartwealthpro.com/Company/Overview/Citizens-Mutual-Fund-2/CMF2?c=184',
#  'https://app.smartwealthpro.com/Company/Overview/Citizens-Santulit-Yojana/CSY?c=1096',
#  'https://app.smartwealthpro.com/Company/Overview/Global-IME-Sammunat-Yojana2/GBIMESY2?c=1092',
#  'https://app.smartwealthpro.com/Company/Overview/Global-IME-Balanced-Fund--1/GIBF1?c=815',
#  'https://app.smartwealthpro.com/Company/Overview/Garima-Samriddhi-Yojana/GSY?c=1049',
#  'https://app.smartwealthpro.com/Company/Overview/Himalayan-8020/H8020?c=935',
#  'https://app.smartwealthpro.com/Company/Overview/HLI-Large-Cap-Fund/HLICF?c=1091',
#  'https://app.smartwealthpro.com/Company/Overview/Kumari-Dhanabriddhi-Yojana/KDBY?c=797',
#  'https://app.smartwealthpro.com/Company/Overview/Kumari-Equity-Fund/KEF?c=729',
#  'https://app.smartwealthpro.com/Company/Overview/Kumari-Sabal-Yojana/KSY?c=956',
# ...

# %%
matured
# Out:
# ['https://app.smartwealthpro.com/Company/Overview/Citizens-Super-30-Mutual-Fund/C30MF?c=885',
#  'https://app.smartwealthpro.com/Company/Overview/Citizens-Mutual-Fund-2/CMF2?c=184',
#  'https://app.smartwealthpro.com/Company/Overview/Citizens-Santulit-Yojana/CSY?c=1096',
#  'https://app.smartwealthpro.com/Company/Overview/Global-IME-Sammunat-Yojana2/GBIMESY2?c=1092',
#  'https://app.smartwealthpro.com/Company/Overview/Global-IME-Balanced-Fund--1/GIBF1?c=815',
#  'https://app.smartwealthpro.com/Company/Overview/Garima-Samriddhi-Yojana/GSY?c=1049',
#  'https://app.smartwealthpro.com/Company/Overview/Himalayan-8020/H8020?c=935',
#  'https://app.smartwealthpro.com/Company/Overview/HLI-Large-Cap-Fund/HLICF?c=1091',
#  'https://app.smartwealthpro.com/Company/Overview/Kumari-Dhanabriddhi-Yojana/KDBY?c=797',
#  'https://app.smartwealthpro.com/Company/Overview/Kumari-Equity-Fund/KEF?c=729']

# %%
all_companys_url={'open_ended':open_ended,"closed_ended":closed_ended,"matured":matured}
all_companys_url
# Out:
# {'open_ended': ['https://app.smartwealthpro.com/Company/Overview/Citizens-Super-30-Mutual-Fund/C30MF?c=885',
#   'https://app.smartwealthpro.com/Company/Overview/Citizens-Mutual-Fund-2/CMF2?c=184',
#   'https://app.smartwealthpro.com/Company/Overview/Citizens-Santulit-Yojana/CSY?c=1096',
#   'https://app.smartwealthpro.com/Company/Overview/Global-IME-Sammunat-Yojana2/GBIMESY2?c=1092',
#   'https://app.smartwealthpro.com/Company/Overview/Global-IME-Balanced-Fund--1/GIBF1?c=815',
#   'https://app.smartwealthpro.com/Company/Overview/Garima-Samriddhi-Yojana/GSY?c=1049',
#   'https://app.smartwealthpro.com/Company/Overview/Himalayan-8020/H8020?c=935',
#   'https://app.smartwealthpro.com/Company/Overview/HLI-Large-Cap-Fund/HLICF?c=1091',
#   'https://app.smartwealthpro.com/Company/Overview/Kumari-Dhanabriddhi-Yojana/KDBY?c=797',
#   'https://app.smartwealthpro.com/Company/Overview/Kumari-Equity-Fund/KEF?c=729',
# ...

# %%
import pickle

with open("all_company_url.pkl","wb") as file:
    pickle.dump(all_companys_url,file)

# %%
with open("all_company_url.pkl","rb") as file:
    loaded=pickle.load(file)

loaded
# Out:
# {'open_ended': ['https://app.smartwealthpro.com/Company/Overview/Citizens-Super-30-Mutual-Fund/C30MF?c=885',
#   'https://app.smartwealthpro.com/Company/Overview/Citizens-Mutual-Fund-2/CMF2?c=184',
#   'https://app.smartwealthpro.com/Company/Overview/Citizens-Santulit-Yojana/CSY?c=1096',
#   'https://app.smartwealthpro.com/Company/Overview/Global-IME-Sammunat-Yojana2/GBIMESY2?c=1092',
#   'https://app.smartwealthpro.com/Company/Overview/Global-IME-Balanced-Fund--1/GIBF1?c=815',
#   'https://app.smartwealthpro.com/Company/Overview/Garima-Samriddhi-Yojana/GSY?c=1049',
#   'https://app.smartwealthpro.com/Company/Overview/Himalayan-8020/H8020?c=935',
#   'https://app.smartwealthpro.com/Company/Overview/HLI-Large-Cap-Fund/HLICF?c=1091',
#   'https://app.smartwealthpro.com/Company/Overview/Kumari-Dhanabriddhi-Yojana/KDBY?c=797',
#   'https://app.smartwealthpro.com/Company/Overview/Kumari-Equity-Fund/KEF?c=729',
# ...

# %% [markdown]
# ## now wxtractt he urls

# %%
loaded['open_ended'][0]
# Out:
# 'https://app.smartwealthpro.com/Company/Overview/Citizens-Super-30-Mutual-Fund/C30MF?c=885'

# %% [markdown]
# ## Nav statements

# %%
# https://app.smartwealthpro.com/MutualFund/NavStatement/Himalayan-80-20/H8020?c=935
#

# %% [markdown]
# # Income statements

# %%
# https://app.smartwealthpro.com/MutualFund/IncomeStatement/Citizens-Mutual-Fund-2/CMF2?c=184

# %%
# /html/body/div[7]/div/div/div[2]/div[2]/div/div[2]/div[2]/div/div/div[3]/table

# %% [markdown]
# # NAV statements

# %%
# /html/body/div[7]/div/div/div[2]/div[2]/div/div[2]/div[2]/div/div/div[3]/table

# %%
from selenium import webdriver

driver = webdriver.Chrome()
from selenium.webdriver.common.by import By
driver.get("https://app.smartwealthpro.com/MutualFund/Overview")

# %%
driver.get("https://app.smartwealthpro.com/MutualFund/IncomeStatement/Citizens-Mutual-Fund-2/CMF2?c=184")

# %%
income_state=driver.find_element(By.XPATH,"/html/body/div[7]/div/div/div[2]/div[2]/div/div[2]/div[2]/div/div/div[3]/table").text

# %%
driver.get("https://app.smartwealthpro.com/MutualFund/NavStatement/Himalayan-80-20/H8020?c=935")

# %%
NAV_statement=driver.find_element(By.XPATH,"/html/body/div[7]/div/div/div[2]/div[2]/div/div[2]/div[2]/div/div/div[3]/table").text

# %% [markdown]
# # data cleanings

# %%
print(income_state)
# Out:
# Particulars
# Baisakh 2083
# Chaitra 2082
# Falgun 2082
# Magh 2082
# Poush 2082
# Income
#           Realized Income
# 2,414,466.00
# 10,083,322.00
# 20,404,591.00
# 20,036,586.00
# 4,512,031.00
# Unrealized Income/(Expense) & Capital Gains
# 3,452,799.00
# 26,604,011.00
# 41,755,811.00
# 21,243,258.00
# 8,306,223.00
# Total Income
# 1,038,333.00
# 16,520,689.00
# 21,351,220.00
# 1,206,672.00
# 12,818,254.00
# Expenses
#           Publication, Listing & Other Expenses
# 346,759.00
# 317,461.00
# 288,034.00
# 257,793.00
# 225,676.00
# Audit Fee
# 112,196.00
# 100,679.00
# 89,534.00
# 78,388.00
# 67,614.00
# Scheme Manager & Depository Fee
# 8,051,540.00
# 7,223,300.00
# 6,352,038.00
# 5,519,592.00
# 4,740,960.00
# Fund Supervisor Fee
# 243,750.00
# 223,750.00
# 210,000.00
# 183,750.00
# 157,500.00
# Total Expenses
# 8,754,245.00
# 7,865,190.00
# 6,939,606.00
# 6,039,523.00
# 5,191,750.00
# Net Income/(Expenses)
# 7,715,912.00
# 8,655,499.00
# 14,411,614.00
# 4,832,851.00
# ...

# %%
all_cols=income_state.split("\n")[:6]

# %%
al_datas=income_state.split("\n")[6:]
al_datas
# Out:
# ['Income',
#  '          Realized Income',
#  '2,414,466.00',
#  '10,083,322.00',
#  '20,404,591.00',
#  '20,036,586.00',
#  '4,512,031.00',
#  'Unrealized Income/(Expense) & Capital Gains',
#  '3,452,799.00',
#  '26,604,011.00',
#  '41,755,811.00',
#  '21,243,258.00',
#  '8,306,223.00',
#  'Total Income',
#  '1,038,333.00',
#  '16,520,689.00',
#  '21,351,220.00',
#  '1,206,672.00',
#  '12,818,254.00',
#  'Expenses',
#  '          Publication, Listing & Other Expenses',
#  '346,759.00',
#  '317,461.00',
#  '288,034.00',
#  '257,793.00',
#  '225,676.00',
#  'Audit Fee',
#  '112,196.00',
#  '100,679.00',
#  '89,534.00',
#  '78,388.00',
#  '67,614.00',
#  'Scheme Manager & Depository Fee',
#  '8,051,540.00',
#  '7,223,300.00',
#  '6,352,038.00',
#  '5,519,592.00',
#  '4,740,960.00',
#  'Fund Supervisor Fee',
#  '243,750.00',
#  '223,750.00',
#  '210,000.00',
#  '183,750.00',
#  '157,500.00',
#  'Total Expenses',
#  '8,754,245.00',
#  '7,865,190.00',
#  '6,939,606.00',
# ...

# %%
[10,20,30].index(20)
# Out:
# 1

# %%
index_pos={}
for item in al_datas:
    if item=="Income" or item=="Expenses":
        index_pos[item]=al_datas.index(item)
    else:
        pass

# %%
def cleaned_income(income_state,cid):
    all_cols=income_state.split("\n")[:6]
    al_datas=income_state.split("\n")[6:]
    for _ in range(5):
        al_datas.insert(20, "0")
    for _ in range(5):
        al_datas.insert(1, "0")
    al_arrays=np.array(al_datas).reshape(int(len(np.array(al_datas))/6),6)
    data=pd.DataFrame(al_arrays)
    data.columns=all_cols
    data['company_id']=cid
    return data

# %%
cleaned_income(income_state,1001)
# Out:
#                                         Particulars    Baisakh 2083  \
# 0                                            Income               0
# 1                                   Realized Income    2,414,466.00
# 2       Unrealized Income/(Expense) & Capital Gains    3,452,799.00
# 3                                      Total Income    1,038,333.00
# 4                                          Expenses               0
# 5             Publication, Listing & Other Expenses      346,759.00
# 6                                         Audit Fee      112,196.00
# 7                   Scheme Manager & Depository Fee    8,051,540.00
# 8                               Fund Supervisor Fee      243,750.00
# 9                                    Total Expenses    8,754,245.00
# 10                            Net Income/(Expenses)    7,715,912.00
# 11          Net Cost Price of Investments till Date  460,348,964.00
#
#       Chaitra 2082     Falgun 2082       Magh 2082      Poush 2082  company_id
# ...

# %%
for _ in range(5):
    al_datas.insert(20, "0")

for _ in range(5):
    al_datas.insert(1, "0")

# %%
import numpy as np

# %%
len(np.array(al_datas))
# Out:
# 72

# %%
72/6
# Out:
# 12.0

# %%
al_arrays=np.array(al_datas).reshape(int(len(np.array(al_datas))/6),6)
data=pd.DataFrame(al_arrays)
data.columns=all_cols
data
# Out:
#                                         Particulars    Baisakh 2083  \
# 0                                            Income               0
# 1                                   Realized Income    2,414,466.00
# 2       Unrealized Income/(Expense) & Capital Gains    3,452,799.00
# 3                                      Total Income    1,038,333.00
# 4                                          Expenses               0
# 5             Publication, Listing & Other Expenses      346,759.00
# 6                                         Audit Fee      112,196.00
# 7                   Scheme Manager & Depository Fee    8,051,540.00
# 8                               Fund Supervisor Fee      243,750.00
# 9                                    Total Expenses    8,754,245.00
# 10                            Net Income/(Expenses)    7,715,912.00
# 11          Net Cost Price of Investments till Date  460,348,964.00
#
#       Chaitra 2082     Falgun 2082       Magh 2082      Poush 2082
# ...

# %% [markdown]
# ## Nav sttements

# %%
print(NAV_statement)
# Out:
# Particulars
# Baisakh 2083
# Chaitra 2082
# Falgun 2082
# Magh 2082
# Poush 2082
# Investments
#           Investment in Listed/Non-Listed Shares
# 763,970,169.50
# 809,884,541.40
# 899,265,417.46
# 817,662,386.20
# 796,053,062.80
# Debentures & Bonds
# 91,784,244.58
# 91,784,244.58
# 91,778,557.57
# 91,778,557.57
# 91,222,557.47
# Investment in IPO/FPO/Right/Bonus
# 13,899,455.05
# 8,947,559.80
# 26,278,840.66
# 42,843,702.65
# 32,995,696.02
# Fixed Income Instruments
# 115,000,000.00
# 115,000,000.00
# 115,000,000.00
# 115,000,000.00
# 115,000,000.00
# Total Investments
# 984,653,869.13
# 1,025,616,345.78
# 1,132,322,815.69
# 1,067,284,646.42
# 1,035,271,316.29
# Current Assets
#           Bank Balance
# 240,595,220.93
# 251,586,421.55
# 140,158,437.29
# 139,505,825.66
# 150,743,518.81
# Other Assets
# 39,249,145.50
# 10,079,379.78
# 22,767,107.90
# 14,340,123.38
# 17,214,810.16
# Total Current Assets
# 279,844,366.43
# 261,665,801.33
# 162,925,545.19
# 153,845,949.04
# ...

# %%
Investments
Current Assets
Current Liabilities

# %%
for _ in range(5):
    al_datas.insert(20, "0")

for _ in range(5):
    al_datas.insert(1, "0")

# %%
index_pos
# Out:
# {'Investments': 6, 'Current Assets': 37, 'Current Liabilities': 56}

# %%
index_pos={}
listed=NAV_statement.split("\n")
for item in listed:
    if item in ["Investments","Current Assets","Current Liabilities"]:
        index_pos[item]=listed.index(item)

for _ in range(5):
    listed.insert(57,"0")

for _ in range(5):
    listed.insert(38,"0")

for _ in range(5):
    listed.insert(7,"0")

# %%
all_datas=np.array(listed)
all_datas
# Out:
# array(['Particulars', 'Baisakh 2083', 'Chaitra 2082', 'Falgun 2082',
#        'Magh 2082', 'Poush 2082', 'Investments', '0', '0', '0', '0', '0',
#        '          Investment in Listed/Non-Listed Shares',
#        '763,970,169.50', '809,884,541.40', '899,265,417.46',
#        '817,662,386.20', '796,053,062.80', 'Debentures & Bonds',
#        '91,784,244.58', '91,784,244.58', '91,778,557.57', '91,778,557.57',
#        '91,222,557.47', 'Investment in IPO/FPO/Right/Bonus',
#        '13,899,455.05', '8,947,559.80', '26,278,840.66', '42,843,702.65',
#        '32,995,696.02', 'Fixed Income Instruments', '115,000,000.00',
#        '115,000,000.00', '115,000,000.00', '115,000,000.00',
#        '115,000,000.00', 'Total Investments', '984,653,869.13',
#        '1,025,616,345.78', '1,132,322,815.69', '1,067,284,646.42',
#        '1,035,271,316.29', 'Current Assets', '0', '0', '0', '0', '0',
#        '          Bank Balance', '240,595,220.93', '251,586,421.55',
# ...

# %%
def cleaned_nav_statements(NAV_statement,cid):
    index_pos={}
    listed=NAV_statement.split("\n")
    for _ in range(5):
        listed.insert(57,"0")
    for _ in range(5):
        listed.insert(38,"0")
    for _ in range(5):
        listed.insert(7,"0")
    all_datas=np.array(listed)
    dfs=pd.DataFrame(all_datas.reshape(int(len(all_datas)/6),6))
    dfs.columns=dfs.iloc[0]
    finals=dfs.iloc[1:,:]
    finals['company_id']=cid
    return finals

# %%
cleaned_nav_statements(NAV_statement,1003)
# Out:
# 0                                        Particulars      Baisakh 2083  \
# 1                                        Investments                 0
# 2             Investment in Listed/Non-Listed Shares    763,970,169.50
# 3                                 Debentures & Bonds     91,784,244.58
# 4                  Investment in IPO/FPO/Right/Bonus     13,899,455.05
# 5                           Fixed Income Instruments    115,000,000.00
# 6                                  Total Investments    984,653,869.13
# 7                                     Current Assets                 0
# 8                                       Bank Balance    240,595,220.93
# 9                                       Other Assets     39,249,145.50
# 10                              Total Current Assets    279,844,366.43
# 11                               Current Liabilities                 0
# 12                                 Other Liabilities              0.00
# ...

# %%
dfs=pd.DataFrame(all_datas.reshape(int(len(all_datas)/6),6))
dfs.columns=dfs.iloc[0]
finals=dfs.iloc[1:,:]
finals
# Out:
# 0                                        Particulars      Baisakh 2083  \
# 1                                        Investments                 0
# 2             Investment in Listed/Non-Listed Shares    763,970,169.50
# 3                                 Debentures & Bonds     91,784,244.58
# 4                  Investment in IPO/FPO/Right/Bonus     13,899,455.05
# 5                           Fixed Income Instruments    115,000,000.00
# 6                                  Total Investments    984,653,869.13
# 7                                     Current Assets                 0
# 8                                       Bank Balance    240,595,220.93
# 9                                       Other Assets     39,249,145.50
# 10                              Total Current Assets    279,844,366.43
# 11                               Current Liabilities                 0
# 12                                 Other Liabilities              0.00
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\HP\\Desktop\\data_extractions\\tables_csv\\nav_statements_income+statements'
